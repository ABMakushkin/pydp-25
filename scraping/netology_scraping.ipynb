# %% [markdown]
# # Основы парсинга и работы с API
#
# Булыгин Олег
#
# * [LinkedIn](linkedin.com/in/obulygin)
# * [Telegram](https://t.me/obulygin91)
# * [Vk](vk.com/obulygin91)
# * email: obulygin91@ya.ru
#
# [Сообщество по Python](https://yandex.ru/q/loves/pythontalk/) на Кью
# [Сообщество по Data Science и анализу данных](https://yandex.ru/q/loves/datatalk/) на Кью

# %%
import pandas as pd

# %%
import requests

# %%
# метод get
res = requests.get('https://netology.ru/blog/')
# res
# res.status_code
# Out:
# 200

# %%
# браузер отрисовал бы страницу на основе данного текста
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru-RU" prefix="og: https://ogp.me/ns#">\n<head>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<link rel="profile" href="https://gmpg.org/xfn/11">\n<title>Медиа Нетологии: об образовании в диджитале</title>\n\n<meta name="description" content="Издание об онлайн-образовании и карьере в ИТ. Пишем о маркетинге, управлении проектами, дизайне, веб-разработке, Data Science и образовании." />\n<meta name="robots" content="max-image-preview:large" />\n<link rel="canonical" href="https://netology.ru/blog/" />\n<link rel="next" href="https://netology.ru/blog/page/2" />\n<meta property="og:locale" content="ru_RU" />\n<meta property="og:site_name" content="Нетология: образовательная платформа" />\n<meta property="og:type" content="article" />\n<meta property="og:title" content="Медиа Нетологии об образовании и карьере в диджитале 🎓" />\n<meta property="og:description" content="Полезное о маркетинге, управлении проектами, дизайне, веб-разработке, Data Science и образовании." />\n<meta property="og:url" content="https://netology.ru/blog/" />\n<meta property="og:image" content="https://netology.ru/blog/wp-content/uploads/2020/01/netology_media.png" />\n<meta property="og:image:secure_url" content="https://netology.ru/blog/wp-content/uploads/2020/01/netology_media.png" />\n<meta property="article:published_time" content="2022-03-23T13:58:26+00:00" />\n<meta property="article:modified_time" content="2022-03-23T18:16:57+00:00" />\n<meta name="twitter:card" content="summary" />\n<meta name="twitter:domain" content="netology.ru" />\n<meta name="twitter:title" content="Медиа Нетологии об образовании и карьере в диджитале 🎓" />\n<meta name="twitter:description" content="Полезное о маркетинге, управлении проектами, дизайне, веб-разработке, Data Science и образовании." />\n<meta name="twitter:image" content="https://netology.ru/blog/wp-content/uploads/2020/01/netology_media.png" />\n\n<link rel="preload" href="https://netology.ru/blog/wp-content/plugins/rate-my-post/public/css/fonts/ratemypost.ttf" type="font/ttf" as="font" crossorigin="anonymous">\n\n<script data-cfasync="false" data-pagespeed-no-defer type="text/javascript">//<![CDATA[\n\tvar gtm4wp_datalayer_name = "dataLayer";\n\tvar dataLayer = dataLayer || [];\n//]]>\n</script>\n<link rel=\'dns-prefetch\' href=\'//netology.ru\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Медиа Нетологии &raquo; Лента" href="https://netology.ru/blog/feed" />\n<link rel="alternate" type="application/rss+xml" title="Медиа Нетологии &raquo; Лента комментариев" href="https://netology.ru/blog/comments/feed" />\n<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/netology.ru\\/blog\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=5.2.12"}};\n\t\t\t!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])?!1:!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203 ...

# %%
# получаем плохой статус
bad_request = requests.get('https://netology.ru/blog/some_page')
bad_request
# Out:
# <Response [404]>

# %%
bad_request.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru-RU" prefix="og: https://ogp.me/ns#">\n<head>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<link rel="profile" href="https://gmpg.org/xfn/11">\n<title>Страница не найдена &#8212; Медиа Нетологии</title>\n\n<meta name="robots" content="noindex" />\n<link rel="canonical" href="https://netology.ru/blog/some_page" />\n\n<link rel="preload" href="https://netology.ru/blog/wp-content/plugins/rate-my-post/public/css/fonts/ratemypost.ttf" type="font/ttf" as="font" crossorigin="anonymous">\n\n<script data-cfasync="false" data-pagespeed-no-defer type="text/javascript">//<![CDATA[\n\tvar gtm4wp_datalayer_name = "dataLayer";\n\tvar dataLayer = dataLayer || [];\n//]]>\n</script>\n<link rel=\'dns-prefetch\' href=\'//netology.ru\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Медиа Нетологии &raquo; Лента" href="https://netology.ru/blog/feed" />\n<link rel="alternate" type="application/rss+xml" title="Медиа Нетологии &raquo; Лента комментариев" href="https://netology.ru/blog/comments/feed" />\n<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/netology.ru\\/blog\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=5.2.12"}};\n\t\t\t!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])?!1:!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);\n\t\t</script>\n<script id="netol-ready">\n\t\t\twindow.advanced_ads_ready=function(e,a){a=a||"complete";var d=function(e){return"interactive"===a?"loading"!==e:"complete"===e};d(document.readyState)?e():document.addEventListener("readystatechange",(function(a){d(a.target.readyState)&&e()}),{once:"interactive"===a})},window.advanced_ads_ready_queue=window.advanced_ads_ready_queue||[];\t\t</script>\n<style type="text/css">\nimg.wp-smiley,\nimg.emoji {\n\tdisplay: inline !important;\n\tborder: none !important;\n\tbox-shadow: none !important;\n\theight: 1em !important;\n\twidth: 1em !import ...

# %%
# как разбирать всю эту разметку? Поможет BeautifulSoup.
from bs4 import BeautifulSoup

# %%
# создаем объекта, через методы которого будем искать нужные теги и извлекать их содержимое
soup = BeautifulSoup(res.text)
soup
# Out:
# <!DOCTYPE html>
# <html lang="ru-RU" prefix="og: https://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <title>Медиа Нетологии: об образовании в диджитале</title>
# <meta content="Издание об онлайн-образовании и карьере в ИТ. Пишем о маркетинге, управлении проектами, дизайне, веб-разработке, Data Science и образовании." name="description"/>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="https://netology.ru/blog/" rel="canonical"/>
# <link href="https://netology.ru/blog/page/2" rel="next"/>
# <meta content="ru_RU" property="og:locale"/>
# <meta content="Нетология: образовательная платформа" property="og:site_name"/>
# <meta content="article" property="og:type"/>
# <meta content="Медиа Нетологии об образовании и карьере в диджитале 🎓" property="og:title"/>
# <meta content="Полезное о маркетинге, управлении проектами, дизайне, веб-разработке, Data Science и образовании." property="og:description"/>
# <meta content="https://netology.ru/blog/" property="og:url"/>
# <meta content="https://netology.ru/blog/wp-content/uploads/2020/01/netology_media.png" property="og:image"/>
# <meta content="https://netology.ru/blog/wp-content/uploads/2020/01/netology_media.png" property="og:image:secure_url"/>
# <meta content="2022-03-23T13:58:26+00:00" property="article:published_time"/>
# <meta content="2022-03-23T18:16:57+00:00" property="article:modified_time"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="netology.ru" name="twitter:domain"/>
# <meta content="Медиа Нетологии об образовании и карьере в диджитале 🎓" name="twitter:title"/>
# <meta content="Полезное о маркетинге, управлении проектами, дизайне, веб-разработке, Data Science и образовании." name="twitter:description"/>
# <meta content="https://netology.ru/blog/wp-content/uploads/2020/01/netology_media.png" name="twitter:image"/>
# <link as="font" crossorigin="anonymous" href="https://netology.ru/blog/wp-content/plugins/rate-my-post/public/css/fonts/ratemypost.ttf" rel="preload" type="font/ttf"/>
# <script data-cfasync="false" data-pagespeed-no-defer="" type="text/javascript">//<![CDATA[
# 	var gtm4wp_datalayer_name = "dataLayer";
# 	var dataLayer = dataLayer || [];
# //]]>
# </script>
# <link href="//netology.ru" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://netology.ru/blog/feed" rel="alternate" title="Медиа Нетологии » Лента" type="application/rss+xml"/>
# <link href="https://netology.ru/blog/comments/feed" rel="alternate" title="Медиа Нетологии » Лента комментариев" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/netology.ru\/blog\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.2.12"}};
# 			!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])?!1:!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <script id="netol-ready">
# 			window.advanced_ads_ready=function(e,a){a=a||"complete";var d=function(e){return"interactive"===a?"loading"!==e:"complete"===e};d(document.readyState)?e():document.addEventListener("readystatechange",(function(a){d(a.target.readyState)&&e()}),{once:"interactive"===a})},window.advanced_ads_ready_queue=window.advanced_ads_ready_queue||[];		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://netology.ru/blog/wp-includes/css/dist/block-library/style.min.css?ver=5.2.12" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="wp-block-library-inline-css" type="text/css">
# .has-text-align-justify{text-align:justify;}
# </style>
# <link href="https://netology.ru/blog/wp-content/plugins/rate-my-post/public/css/rate-my-post.css?ver=3.3.4" id="rate-my-post-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://netology.ru/blog/wp-includes/js/mediaelement/mediaelementplayer-legacy.min.css?ver=4.2.6-78496d1" id="mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://netology.ru/blog/wp-includes/js/mediaelement/wp-mediaelement.min.css?ver=5.2.12" id="wp-mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://netology.ru/blog/wp-content/themes/aquene-child-theme/style.css?ver=1.8.0" id="aquene-style-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="aquene-style-inline-css" type="text/css">
# #page .byline { clip: rect(1px, 1px, 1px, 1px); height: 1px; position: absolute; overflow: hidden; width: 1px; }
# </style>
# <link href="https://netology.ru/blog/wp-content/themes/aquene-child-theme/assets/css/adaptive.css?ver=1.1.8" id="adaptive-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://netology.ru/blog/wp-content/themes/aquene/assets/css/font-awesome.min.css?ver=4.7.0" id="font-awesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://netology.ru/blog/wp-content/themes/aquene/assets/css/print-style.min.css?ver=1.0.0" id="aquene-print-style-css" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Lato%3A300%2C300i%2C400%2C400i%2C700%2C700i%7CLato%3A300%2C300i%2C400%2C400i%2C700%2C700i&amp;subset=latin%2Clatin-ext%2Ccyrillic%2Ccyrillic-ext&amp;display=swap" id="aquene-google-fonts-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://netology.ru/blog/wp-content/plugins/jetpack/css/jetpack.css?ver=8.2.4" id="jetpack_css-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://netology.ru/blog/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" type="text/javascript"></script>
# <script src="https://netology.ru/blog/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript"></script>
# <script type="text/javascript">
# var mejsL10n = {"language":"ru","strings":{"mejs.install-flash":"Flash player \u043f\u043b\u0430\u0433\u0438\u043d \u0431\u044b\u043b \u043e\u0442\u043a\u043b\u044e\u0447\u0435\u043d \u0438\u043b\u0438 \u043d\u0435 \u0431\u044b\u043b \u0443\u0441\u0442\u0430\u043d\u043e\u0432\u043b\u0435\u043d \u0432 \u0432\u0430\u0448\u0435\u043c \u0431\u0440\u0430\u0443\u0437\u0435\u0440\u0435. \u041f\u043e\u0436\u0430\u043b\u0443\u0439\u0441\u0442\u0430, \u0432\u043a\u043b\u044e\u0447\u0438\u0442\u0435 \u043f\u043b\u0430\u0433\u0438\u043d Flash player \u0438\u043b\u0438 \u0441\u043a\u0430\u0447\u0430\u0439\u0442\u0435 \u043f\u043e\u0441\u043b\u0435\u0434\u043d\u044e\u044e \u0432\u0435\u0440\u0441\u0438\u044e \u0441 https:\/\/get.adobe.com\/flashplayer\/","mejs.fullscreen-off":"\u0412\u044b\u043a\u043b\u044e\u0447\u0438\u0442\u044c \u043f\u043e\u043b\u043d\u044b\u0439 \u044d\u043a\u0440\u0430\u043d","mejs.fullscreen-on":"\u041f\u043e\u043b\u043d\u044b\u0439 \u044d\u043a\u0440\u0430\u043d","mejs.download-video":"\u0421\u043a\u0430\u0447\u0430\u0442\u044c \u0432\u0438\u0434\u0435\u043e","mejs.fullscreen":"\u041d\u0430 \u0432\u0435\u0441\u044c \u044d\u043a\u0440\u0430\u043d","mejs.time-jump-forward":["\u0412\u043f\u0435\u0440\u0451\u0434 \u043d\u0430 1 \u0441\u0435\u043a\u0443\u043d\u0434\u0443","\u0412\u043f\u0435\u0440\u0435\u0434 \u043d\u0430 %1 \u0441\u0435\u043a\u0443\u043d\u0434"],"mejs.loop":"\u0412\u043a\u043b\u044e\u0447\u0438\u0442\u044c\/\u0432\u044b\u043a\u043b\u044e\u0447\u0438\u0442\u044c \u0437\u0430\u0446\u0438\u043a\u043b\u0438\u0432\u0430\u043d\u0438\u0435","mejs.play":"\u0412\u043e\u0441\u043f\u0440\u043e\u0438\u0437\u0432\u0435\u0441\u0442\u0438","mejs.pause":"\u041f\u0430\u0443\u0437\u0430","mejs.close":"\u0417\u0430\u043a\u0440\u044b\u0442\u044c","mejs.time-slider":"\u0428\u043a\u0430\u043b\u0430 \u0432\u0440\u0435\u043c\u0435\u043d\u0438","mejs.time-help-text":"\u0418\u0441\u043f\u043e\u043b\u044c\u0437\u0443\u0439\u0442\u0435 \u043a\u043b\u0430\u0432\u0438\u0448\u0438 \u0432\u043b\u0435\u0432\u043e\/\u0432\u043f\u0440\u0430\u0432\u043e, \u0447\u0442\u043e\u0431\u044b \u043f\u0435\u0440\u0435\u043c\u0435\u0441\u0442\u0438\u0442\u044c\u0441\u044f \u043d\u0430 \u043e\u0434\u043d\u0443 \u0441\u0435\u043a\u0443\u043d\u0434\u0443; \u0432\u0432\u0435\u0440\u0445\/\u0432\u043d\u0438\u0437, \u0447\u0442\u043e\u0431\u044b \u043f\u0435\u0440\u0435\u043c\u0435\u0441\u0442\u0438\u0442\u044c\u0441\u044f \u043d\u0430 \u0434\u0435\u0441\u044f\u0442\u044c \u0441\u0435\u043a\u0443\u043d\u0434.","mejs.time-skip-back":["\u041f\u0435\u0440\u0435\u0439\u0442\u0438 \u043d\u0430\u0437\u0430\u0434 \u043d\u0430 1 \u0441\u0435\u043a\u0443\u043d\u0434\u0443","\u041d\u0430\u0437\u0430\u0434 \u043d\u0430 %1 \u0441\u0435\u043a\u0443\u043d\u0434"],"mejs.captions-subtitles":"\u0421\u0443\u0431\u0442\u0438\u0442\u0440\u044b","mejs.captions-chapters":"\u0413\u043b\u0430\u0432\u044b","mejs.none":"\u041d\u0435\u0442","mejs.mute-toggle":"\u0412\u043a\u043b\u044e\u0447\u0438\u0442\u044c\/\u0432\u044b\u043a\u043b\u044e\u0447\u0438\u0442\u044c \u0437\u0432\u0443\u043a","mejs.volume-help-text":"\u0418\u0441\u043f\u043e\u043b\u044c\u0437\u0443\u0439\u0442\u0435 \u043a\u043b\u0430\u0432\u0438\u0448\u0438 \u0432\u0432\u0435\u0440\u0445\/\u0432\u043d\u0438\u0437, \u0447\u0442\u043e\u0431\u044b \u0443\u0432\u0435\u043b\u0438\u0447\u0438\u0442\u044c \u0438\u043b\u0438 \u0443\u043c\u0435\u043d\u044c\u0448\u0438\u0442\u044c \u0433\u0440\u043e\u043c\u043a\u043e\u0441\u0442\u044c.","mejs.unmute":"\u0412\u043a\u043b\u044e\u0447\u0438\u0442\u044c \u0437\u0432\u0443\u043a","mejs.mute":"\u0411\u0435\u0437 \u0437\u0432\u0443\u043a\u0430","mejs.volume-slider":"\u0420\u0435\u0433\u0443\u043b\u044f\u0442\u043e\u0440 \u0433\u0440\u043e\u043c\u043a\u043e\u0441\u0442\u0438","mejs.video-player":"\u0412\u0438\u0434\u0435\u043e\u043f\u043b\u0435\u0435\u0440","mejs.audio-player":"\u0410\u0443\u0434\u0438\u043e\u043f\u043b\u0435\u0435\u0440","mejs.ad-skip":"\u041f\u0440\u043e\u043f\u0443 ...
# </script>
# <script src="https://netology.ru/blog/wp-includes/js/mediaelement/mediaelement-and-player.min.js?ver=4.2.6-78496d1" type="text/javascript"></script>
# <script src="https://netology.ru/blog/wp-includes/js/mediaelement/mediaelement-migrate.min.js?ver=5.2.12" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var _wpmejsSettings = {"pluginPath":"\/blog\/wp-includes\/js\/mediaelement\/","classPrefix":"mejs-","stretching":"responsive"};
# /* ]]> */
# </script>
# <script src="https://netology.ru/blog/wp-content/themes/aquene-child-theme/assets/js/adaptive.js?ver=1.4.8" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var url_name = {"ajaxurl":"https:\/\/netology.ru\/blog\/wp-admin\/admin-ajax.php"};
# /* ]]> */
# </script>
# <script src="https://netology.ru/blog/wp-content/themes/aquene-child-theme/assets/js/loadmore.js?ver=6.6.0" type="text/javascript"></script>
# <script src="https://netology.ru/blog/wp-content/plugins/jetpack/_inc/build/spin.min.js?ver=1.3" type="text/javascript"></script>
# <script src="https://netology.ru/blog/wp-content/plugins/jetpack/_inc/build/jquery.spin.min.js?ver=1.3" type="text/javascript"></script>
# <link href="https://netology.ru/blog/wp-json/" rel="https://api.w.org/"/>
# <link href="" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://netology.ru/blog/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 5.2.12" name="generator"/>
# <script data-cfasync="false" data-pagespeed-no-defer="" type="text/javascript">//<![CDATA[
# 	var dataLayer_content = [];
# 	dataLayer.push( dataLayer_content );//]]>
# </script>
# <script data-cfasync="false">//<![CDATA[
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.'+'js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-TN84HZG');//]]>
# </script>
# <style type="text/css">img#wpstats{display:none}</style><style type="text/css">.broken_link, a.broken_link {
# 	text-decoration: line-through;
# }</style><link href="https://netology.ru/blog/wp-content/uploads/2020/05/cropped-android-chrome-512x512-32x32.png" rel="icon" sizes="32x32"/>
# <link href="https://netology.ru/blog/wp-content/uploads/2020/05/cropped-android-chrome-512x512-192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://netology.ru/blog/wp-content/uploads/2020/05/cropped-android-chrome-512x512-180x180.png" rel="apple-touch-icon-precomposed"/>
# <meta content="https://netology.ru/blog/wp-content/uploads/2020/05/cropped-android-chrome-512x512-270x270.png" name="msapplication-TileImage"/>
# <style id="wp-custom-css" type="text/css">
# 			.socials-footer__item--fb {
# 	display: none;
# }
#
# .socials-footer__item--insta {
# 	display: none;
# }
#
# .socials__link--insta {
# 	display: none;
# }
# 		</style>
# </head>
# <body>
# <div class="wrap-header">
# <header class="header">
# <h1 class="logo"><a class="logo__link" href="https://netology.ru/" target="_blank">Нетология</a><img alt="Нетология Медиа" class="logo__img" src="wp-content/themes/aquene-child-theme/img/logo.svg"/><a class="logo__media" href="/" target="_blank">Медиа</a><span class="logo__slogan">всё о карьере и профессиях</span></h1>
# <div class="actions">
# <a class="actions__add" href="/blog/terms" target="_blank">Прислать статью</a>
# <div class="socials">
# <a class="socials__link socials__link--insta" href="https://www.instagram.com/netology_official/?hl=ru" target="_blank"><i class="icon-insta"></i></a>
# <a class="socials__link socials__link--tg" href="https://t.me/netology_ru" target="_blank"><i class="icon-tg"></i></a>
# </div>
# <div class="wrap-menu">
# <button class="menu-btn" type="button"><span class="line"></span></button>
# <nav class="menu">
# <a class="menu__link menu__link--main" href="/blog/work_together" target="_blank">Сотрудничество</a>
# <a class="menu__link" href="/about" target="_blank">О Нетологии</a>
# <a class="menu__link" href="/free" target="_blank">Учиться бесплатно</a>
# <a class="menu__link" href="/navigation" target="_blank">Каталог курсов</a>
# </nav>
# </div>
# </div>
# </header>
# </div>
# <div class="wrap-header-bottom">
# <div class="header-bottom">
# <ul class="filters" id="menu-top_categories_menu"><li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-23481" id="menu-item-23481"><a href="https://netology.ru/blog/category/professions">Современные профессии</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-23484" id="menu-item-23484"><a href="https://netology.ru/blog/category/what-is">Разобраться</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-23468" id="menu-item-23468"><a href="https://netology.ru/blog/category/how-to">Руководство</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-23461" id="menu-item-23461"><a href="https://netology.ru/blog/category/career">Карьера</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-23464" id="menu-item-23464"><a href="https://netology.ru/blog/category/productivity">Продуктивность</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-23482" id="menu-item-23482"><a href="https://netology.ru/blog/category/experience">Личный опыт</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24335" id="menu-item-24335"><a href="https://netology.ru/blog/category/education">Научиться учиться</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-23467" id="menu-item-23467"><a href="https://netology.ru/blog/category/books">Книжная полка</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-23483" id="menu-item-23483"><a href="https://netology.ru/blog/category/business">Предпринимательство</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-23466" id="menu-item-23466"><a href="https://netology.ru/blog/category/netologiya">Нетология</a></li>
# </ul>
# <p></p>
# <div class="search">
# <button class="search__button" type="button"><i class="icon-search"></i></button>
# <form action="/blog/" class="search__form" method="get">
# <input class="search__input" name="s" type="search"/>
# <button class="search__btn" type="submit"><i class="icon-search"></i></button>
# </form>
# </div>
# </div>
# </div>
# <div class="site-content" id="content">
# <div class="wrap">
# <div class="content main-news">
# <div class="main-news__item main-news__item--main">
# <div class="main-news__img">
# <a href="https://netology.ru/blog/08-2021-vybrat-online-kurs" target="_blank">
# <img alt="Как выбрать онлайн-курс: форматы, критерии, вопросы менеджеру" src="https://netology.ru/blog/wp-content/uploads/2021/08/Как-выбрать-онлайн-курс_-форматы-критерии-вопросы-менеджеру-2.png" style="width: 100%;"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/education" style="background:#4bd0a0"><span style="background:#4bd0a0">Научиться учиться</span></a>
# </div>
# <div class="meta">
# <div class="meta__date">10 августа 2021</div>
# <div class="meta__views"><i class="icon-views"></i>17 504</div>
# </div>
# </div>
# <div class="main-news__content">
# <h2 class="main-news__title"><a class="main-news__link" href="https://netology.ru/blog/08-2021-vybrat-online-kurs" target="_blank">Как выбрать онлайн-курс: форматы, критерии, вопросы менеджеру</a></h2>
# <div class="main-news__txt">
# <p></p>
# </div>
# </div>
# </div>
# <div class="main-news__item">
# <div class="main-news__img ">
# <a href="https://netology.ru/blog/08-2021-diploma" target="_blank">
# <img alt="Диплом, сертификат, УПК — какие документы выдаются на онлайн-курсах" src="https://netology.ru/blog/wp-content/uploads/2021/08/Диплом-сертификат-УПК-2.png"/>
# </a>
# </div>
# <div class="tags">
# <a class="tags__item" href="/blog/category/education" style="background:#4bd0a0"><span style="background:#4bd0a0">Научиться учиться</span></a>
# </div>
# <h2 class="main-news__title"><a class="main-news__link" href="https://netology.ru/blog/08-2021-diploma" target="_blank">Диплом, сертификат, УПК — какие документы выдаются на онлайн-курсах</a></h2>
# <div class="meta">
# <div class="meta__date">11 августа 2021</div>
# <div class="meta__views"><i class="icon-views"></i>18 871</div>
# </div>
# </div>
# <div class="main-news__item">
# <div class="main-news__img main-news__img--lines">
# <a href="https://netology.ru/blog/12-2019-kak-poluchit-nalogovyy-vychet" target="_blank">
# <img alt="Как получить налоговый вычет за обучение: на что обратить внимание и стоит ли оформлять его через посредников" src="https://netology.ru/blog/wp-content/uploads/2019/12/Как-получить-налоговый-вычет-за-обучение.png"/>
# </a>
# </div>
# <div class="tags">
# <a class="tags__item" href="/blog/category/education" style="background:#4bd0a0"><span style="background:#4bd0a0">Научиться учиться</span></a>
# </div>
# <h2 class="main-news__title"><a class="main-news__link" href="https://netology.ru/blog/12-2019-kak-poluchit-nalogovyy-vychet" target="_blank">Как получить налоговый вычет за обучение: на что обратить внимание и стоит ли оформлять его через посредников</a></h2>
# <div class="meta">
# <div class="meta__date">11 декабря 2019</div>
# <div class="meta__views"><i class="icon-views"></i>145 930</div>
# </div>
# </div>
# </div>
# </div>
# <div class="wrap wrap--gray" id="primary">
# <div class="content">
# <div class="news">
# <div class="news__item">
# <h3 class="news__title"><a class="news__link" href="https://netology.ru/blog/news/25-02-2022-startup-efficiency" target="_blank">Частые эксперименты помогают стартапам повысить производительность до 100% в год</a></h3>
# <div class="news__txt">
# <p></p><p>У стартапов, которые часто экспериментируют, заметно повышается производительность. Такую закономерность выявили исследователи из Гарвардского университета и Университета Дьюка, передаёт Ariyh.Учёные в течение четырёх лет анализировали работу более…</p>
# </div>
# <div class="news__meta">
# <div class="news__date">25 февраля 2022</div>
# </div>
# </div><div class="news__item">
# <h3 class="news__title"><a class="news__link" href="https://netology.ru/blog/news/24-02-2022-russians-four-days-work-week" target="_blank">Каждый второй россиянин на пятидневке мечтает о трёх выходных</a></h3>
# <div class="news__txt">
# <p></p><p>56% жителей страны хотели бы работать четыре дня в неделю по десять часов вместо пяти дней по восемь — выяснили в SuperJob, опросив 1 600 человек старше…</p>
# </div>
# <div class="news__meta">
# <div class="news__date">24 февраля 2022</div>
# </div>
# </div><div class="news__item">
# <h3 class="news__title"><a class="news__link" href="https://netology.ru/blog/news/24-02-2022-degree-february-results" target="_blank">Направление «Высшее образование» Нетологии: новые программы, мероприятия и полезные статьи</a></h3>
# <div class="news__txt">
# <p></p><p>Вот-вот наступит долгожданный март, а там начнутся и первые поступления. В новом дайджесте команда «Высшего образования» рассказывает, что ей удалось в последний зимний месяц.Готовились (и продолжаем готовиться!)…</p>
# </div>
# <div class="news__meta">
# <div class="news__date">24 февраля 2022</div>
# </div>
# </div><div class="news__item">
# <h3 class="news__title"><a class="news__link" href="https://netology.ru/blog/news/24-02-2022-social-media-work" target="_blank">Работа.ру: почти треть россиян ищет вакансии через соцсети и мессенджеры</a></h3>
# <div class="news__txt">
# <p></p><p>В России 18% соискателей предпочитают искать работу в соцсетях, ещё 12% — в специальных каналах в мессенджерах. К такому выводу пришли исследователи сервиса Работа.ру, передаёт ТАСС.Опрос показал,…</p>
# </div>
# <div class="news__meta">
# <div class="news__date">24 февраля 2022</div>
# </div>
# </div>
# </div>
# <div id="loadmore">
# <button class="btn news-btn" data-count-news="176" data-paged="1" href="#" type="button">Больше новостей</button>
# </div>
# </div>
# </div>
# <div class="wrap">
# <div class="content">
# <div class="posts">
# <div class="posts__item" id="post-30796">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-help-to-business" target="_blank">
# <img alt="Как помочь бизнесу в текущей ситуации: советы предпринимателей и экспертов" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обложка-мал_рубик.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/business" style="background:#5d00f5"><span style="background:#5d00f5">Предпринимательство</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-help-to-business" target="_blank">Как помочь бизнесу в текущей ситуации: советы предпринимателей и экспертов</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">23 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30777">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-finance-protection-in-crisis" target="_blank">
# <img alt="Как защитить финансы бизнеса в сложные времена" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обложка-мал_зонт.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/business" style="background:#5d00f5"><span style="background:#5d00f5">Предпринимательство</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-finance-protection-in-crisis" target="_blank">Как защитить финансы бизнеса в сложные времена</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">22 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30736">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-freelance-transformation" target="_blank">
# <img alt="Трансформация фриланса: почему независимые профессионалы объединяются в команды" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обл_главная_команда_shutterstock.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-freelance-transformation" target="_blank">Трансформация фриланса: почему независимые профессионалы объединяются в команды</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">22 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30719">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-deal-with-anxiety" target="_blank">
# <img alt="7 способов справиться с тревогой: советы от клинического психолога" src="https://netology.ru/blog/wp-content/uploads/2022/03/Справляемся-с-тревогой_превью.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-deal-with-anxiety" target="_blank">7 способов справиться с тревогой: советы от клинического психолога</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">18 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30687">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-tsifrovye-professii-b2g" target="_blank">
# <img alt="«Цифровые профессии»: как мы обучали IT в федеральном проекте" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обложка_мал_книжки.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/netologiya" style="background:#0066ff"><span style="background:#0066ff">Нетология</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-tsifrovye-professii-b2g" target="_blank">«Цифровые профессии»: как мы обучали IT в федеральном проекте</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">17 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30665">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-developers-types" target="_blank">
# <img alt="Каким программистом стать — рассказываем о популярных направлениях" src="https://netology.ru/blog/wp-content/uploads/2022/03/Каким-программистом-стать_превью.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-developers-types" target="_blank">Каким программистом стать — рассказываем о популярных направлениях</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">16 марта 2022</div>
# </div>
# </div></div>
# <div class="post-digest">
# <div class="post">
# <h3 class="post__title"><a class="post__link" href="/blog/06-2021-what-is-nft" target="_blank">Мир обсуждает NFT: рассказываем, что это за токен и для чего он нужен</a></h3>
# <div class="post__img">
# <img alt="Мир обсуждает NFT: рассказываем, что это за токен и для чего он нужен" src="https://netology.ru/blog/wp-content/uploads/2021/06/660х370.png"/>
# </div>
# </div>
# <div class="digest" id="subscription-digest">
# <div class="digest__img"><img alt="Дайджест Нетологии" src="wp-content/themes/aquene-child-theme/img/img-11.png"/></div>
# <div class="digest__title">Дайджест Нетологии</div>
# <div class="digest__txt">
# <p>Свежие статьи, видео, лекции и скидки — раз в две недели по четвергам</p>
# </div>
# <form action="#" class="digest__form" method="POST">
# <div class="digest__item">
# <input class="digest__input" name="email" placeholder="Email" type="email"/>
# </div>
# <div class="digest__item">
# <button class="btn btn--red" type="submit">Хочу подписку</button>
# </div>
# <div class="digest__item">
# <p>Нажимая на кнопку, вы даёте согласие на обработку своих персональных данных</p>
# </div>
# </form>
# </div>
# <div class="digest" id="thanks-text-digest" style="display:none;">
# <div class="digest__img"><img alt="" src="wp-content/themes/aquene-child-theme/img/img-11.png"/></div>
# <div class="digest__title">Спасибо,<br/> что с нами!</div>
# <div class="digest__txt">
# <p>Спасибо за подписку!</p>
# </div>
# <div class="letter">
# <img alt="конверт" src="wp-content/themes/aquene-child-theme/img/img-16.png" srcset=""/>
# </div>
# </div>
# </div>
# <div class="posts">
# <div class="posts__item" id="post-30647">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-it-happens" target="_blank">
# <img alt="Как сообщить, что вы всё уронили: навыки поведения в ситуации, когда всё пошло не по плану" src="https://netology.ru/blog/wp-content/uploads/2022/03/Всё-не-по-плану_превью.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/how-to" style="background:#5d00f5"><span style="background:#5d00f5">Руководство</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-it-happens" target="_blank">Как сообщить, что вы всё уронили: навыки поведения в ситуации, когда всё пошло не по плану</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">15 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30621">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-data-science-digest" target="_blank">
# <img alt="Data Science-дайджест: что почитать, посмотреть и попробовать в марте 2022" src="https://netology.ru/blog/wp-content/uploads/2022/03/Data-Science-дайджест-март.png"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/books" style="background:#0066ff"><span style="background:#0066ff">Книжная полка</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-data-science-digest" target="_blank">Data Science-дайджест: что почитать, посмотреть и попробовать в марте 2022</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">14 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30603">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-self-help" target="_blank">
# <img alt="Как помочь себе в условиях неопределённости и стресса — советы психоаналитика" src="https://netology.ru/blog/wp-content/uploads/2022/03/Самоподдержка_превью.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-self-help" target="_blank">Как помочь себе в условиях неопределённости и стресса — советы психоаналитика</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">11 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30581">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-illustrator" target="_blank">
# <img alt="Кто такой иллюстратор, чем он занимается и сколько зарабатывает" src="https://netology.ru/blog/wp-content/uploads/2022/03/shubham-dhage-VEEqzwGwnpk-unsplash-1.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/professions" style="background:#4BD0A0"><span style="background:#4BD0A0">Современные профессии</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-illustrator" target="_blank">Кто такой иллюстратор, чем он занимается и сколько зарабатывает</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">10 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30543">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-kak-privlekat-it-vypusknikov" target="_blank">
# <img alt="Как работодателям привлекать начинающих IT-специалистов" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обложка_гл_зел.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-kak-privlekat-it-vypusknikov" target="_blank">Как работодателям привлекать начинающих IT-специалистов</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">10 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30535">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-unic" target="_blank">
# <img alt="«Я в безопасности»: бесплатный курс, который поможет пережить условия неопределённости" src="https://netology.ru/blog/wp-content/uploads/2022/03/Я-в-безопасности_превью.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/netologiya" style="background:#0066ff"><span style="background:#0066ff">Нетология</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-unic" target="_blank">«Я в безопасности»: бесплатный курс, который поможет пережить условия неопределённости</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">9 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30487">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-cjm-v-social-media" target="_blank">
# <img alt="Как Customer Journey Map помогает повысить продажи в Instagram" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обложка-мал_для-CJM.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/productivity" style="background:#4bd0a0"><span style="background:#4bd0a0">Продуктивность</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-cjm-v-social-media" target="_blank">Как Customer Journey Map помогает повысить продажи в Instagram</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">5 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30428">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-programming-languages" target="_blank">
# <img alt="Языки программирования: для чего нужны, какие популярны, как выбрать и с чего начать изучение" src="https://netology.ru/blog/wp-content/uploads/2022/03/Робот_превью.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-programming-languages" target="_blank">Языки программирования: для чего нужны, какие популярны, как выбрать и с чего начать изучение</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">3 марта 2022</div>
# </div>
# </div>
# <div class="posts__item" id="post-30268">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-copyright" target="_blank">
# <img alt="Как нарушение авторских прав влияет на самого автора и как предотвратить кражу контента" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обложка_главная_стаканы.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-copyright" target="_blank">Как нарушение авторских прав влияет на самого автора и как предотвратить кражу контента</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">1 марта 2022</div>
# </div>
# </div> </div>
# <button class="btn posts-btn" data-exclude="22658,22672,7189" data-page="1" id="loadmore-posts" type="button">Ещё статьи</button>
# </div>
# </div>
# </div>
# <div class="wrap-footer">
# <footer class="footer">
# <div class="logo-socials">
# <div class="logo-footer">
# <div class="logo-footer__net">Нетология</div>
# <img alt="Нетология Медиа" class="logo-footer__img" src="/blog/wp-content/themes/aquene-child-theme/img/logo-footer.svg"/>
# <span class="logo-footer__media">Медиа</span>
# </div>
# <ul class="socials-footer">
# <li class="socials-footer__item socials-footer__item--fb"><a class="socials-footer__link" href="https://www.facebook.com/netology.ru" target="_blank"><i class="icon-fb"></i></a></li>
# <li class="socials-footer__item socials-footer__item--insta"><a class="socials-footer__link" href="https://www.instagram.com/netology_official/?hl=ru" target="_blank"><i class="icon-insta"></i></a></li>
# <li class="socials-footer__item socials-footer__item--yt"><a class="socials-footer__link" href="https://www.youtube.com/c/netologytv/" target="_blank"><i class="icon-yt"></i></a></li>
# <li class="socials-footer__item socials-footer__item--vk"><a class="socials-footer__link" href="https://vk.com/netology_ru" target="_blank"><i class="icon-vk"></i></a></li>
# <li class="socials-footer__item socials-footer__item--tg"><a class="socials-footer__link" href="https://t.me/netology_ru" target="_blank"><i class="icon-tg"></i></a></li>
# </ul>
# <p class="copy">© Нетология-групп, 2011‐2021</p>
# </div>
# <div class="menus-footer">
# <ul class="menu-footer">
# <li class="menu-footer__item"><a class="menu-footer__link" href="/blog/o-proekte" target="_blank">О проекте</a></li>
# <li class="menu-footer__item"><a class="menu-footer__link" href="/blog/mediakit" target="_blank">Медиакит</a></li>
# <li class="menu-footer__item"><a class="menu-footer__link" href="/blog/work_together" target="_blank">Сотрудничество</a></li>
# </ul>
# <ul class="menu-footer">
# <li class="menu-footer__item"><a class="menu-footer__link" href="/about" target="_blank">О Нетологии</a></li>
# <li class="menu-footer__item"><a class="menu-footer__link" href="/free" target="_blank">Учиться бесплатно</a></li>
# <li class="menu-footer__item"><a class="menu-footer__link" href="/navigation" target="_blank">Каталог курсов</a></li>
# </ul>
# </div>
# <form action="#" class="sub-form" id="subscription" method="POST">
# <div class="sub-form__item sub-form__item--line">
# <input class="sub-form__input" name="email" placeholder="Email" type="email"/>
# <button class="btn btn--red" type="submit">Хочу подписку</button>
# </div>
# <div class="sub-form__item">
# <p>Нажимая на кнопку, вы даёте согласие на обработку своих персональных данных</p>
# </div>
# </form>
# <div class="sub-form" id="thanks-text" style="display:none;">
# <div class="sub-form__item sub-form__item--line">
# <span style="color:white;font-size:16px;">Спасибо за подписку!</span>
# </div>
# </div>
# </footer>
# </div>
# <div class="wrap-cookies" id="cookie_show">
# <div class="cookies mobile-hidden">
# <p>Пользуясь нашим сайтом, вы соглашаетесь с тем, что <a href="/legal/24">мы используем cookies</a></p>
# <button id="cookie_ok" type="button">ОК</button>
# </div>
# <div class="cookies pc-hidden">
# <p>Мы используем <a href="/legal/24">cookies</a></p>
# <button id="cookie_ok_mobile" type="button"></button>
# </div>
# </div>
# <script type="text/javascript">
# 		//<![CDATA[
# 		var infiniteScroll = JSON.parse( decodeURIComponent( '%7B%22settings%22%3A%7B%22id%22%3A%22main%22%2C%22ajaxurl%22%3A%22https%3A%5C%2F%5C%2Fnetology.ru%5C%2Fblog%5C%2F%3Finfinity%3Dscrolling%22%2C%22type%22%3A%22click%22%2C%22wrapper%22%3Afalse%2C%22wrapper_class%22%3A%22infinite-wrap%22%2C%22footer%22%3Atrue%2C%22click_handle%22%3A%221%22%2C%22text%22%3A%22%5Cu0411%5Cu043e%5Cu043b%5Cu044c%5Cu0448%5Cu0435%20%5Cu043f%5Cu043e%5Cu043b%5Cu0435%5Cu0437%5Cu043d%5Cu044b%5Cu0445%20%5Cu0441%5Cu0442%5Cu0430%5Cu0442%5Cu0435%5Cu0439%22%2C%22totop%22%3A%22Scroll%20back%20to%20top%22%2C%22currentday%22%3A%2201.03.22%22%2C%22order%22%3A%22DESC%22%2C%22scripts%22%3A%5B%5D%2C%22styles%22%3A%5B%5D%2C%22google_analytics%22%3Afalse%2C%22offset%22%3A1%2C%22history%22%3A%7B%22host%22%3A%22netology.ru%5C%2Fblog%22%2C%22path%22%3A%22%5C%2Fpage%5C%2F%25d%22%2C%22use_trailing_slashes%22%3Afalse%2C%22parameters%22%3A%22%22%7D%2C%22query_args%22%3A%7B%22error%22%3A%22%22%2C%22m%22%3A%22%22%2C%22p%22%3A0%2C%22post_parent%22%3A%22%22%2C%22subpost%22%3A%22%22%2C%22subpost_id%22%3A%22%22%2C%22attachment%22%3A%22%22%2C%22attachment_id%22%3A0%2C%22name%22%3A%22%22%2C%22pagename%22%3A%22%22%2C%22page_id%22%3A0%2C%22second%22%3A%22%22%2C%22minute%22%3A%22%22%2C%22hour%22%3A%22%22%2C%22day%22%3A0%2C%22monthnum%22%3A0%2C%22year%22%3A0%2C%22w%22%3A0%2C%22category_name%22%3A%22%22%2C%22tag%22%3A%22%22%2C%22cat%22%3A%22%22%2C%22tag_id%22%3A%22%22%2C%22author%22%3A%22%22%2C%22author_name%22%3A%22%22%2C%22feed%22%3A%22%22%2C%22tb%22%3A%22%22%2C%22paged%22%3A0%2C%22meta_key%22%3A%22%22%2C%22meta_value%22%3A%22%22%2C%22preview%22%3A%22%22%2C%22s%22%3A%22%22%2C%22sentence%22%3A%22%22%2C%22title%22%3A%22%22%2C%22fields%22%3A%22%22%2C%22menu_order%22%3A%22%22%2C%22embed%22%3A%22%22%2C%22category__in%22%3A%5B%5D%2C%22category__not_in%22%3A%5B%5D%2C%22category__and%22%3A%5B%5D%2C%22post__in%22%3A%5B%5D%2C%22post__not_in%22%3A%5B%5D%2C%22post_name__in%22%3A%5B%5D%2C%22tag__in%22%3A%5B%5D%2C%22tag__not_in%22%3A%5B%5D%2C%22tag__and%22%3A%5B%5D%2C%22tag_slug__in%22%3A%5B%5D%2C%22tag_slug__and%22%3A%5B%5D%2C%22post_parent__in%22%3A%5B%5D%2C%22post_parent__not_in%22%3A%5B%5D%2C%22author__in%22%3A%5B%5D%2C%22author__not_in%22%3A%5B%5D%2C%22posts_per_page%22%3A6%2C%22ignore_sticky_posts%22%3Afalse%2C%22suppress_filters%22%3Afalse%2C%22cache_results%22%3Atrue%2C%22update_post_term_cache%22%3Atrue%2C%22lazy_load_term_meta%22%3Atrue%2C%22update_post_meta_cache%22%3Atrue%2C%22post_type%22%3A%22%22%2C%22nopaging%22%3Afalse%2C%22comments_per_page%22%3A%2250%22%2C%22no_found_rows%22%3Afalse%2C%22order%22%3A%22DESC%22%7D%2C%22query_before%22%3A%222022-03-24%2019%3A30%3A11%22%2C%22last_post_date%22%3Afalse%2C%22body_class%22%3A%22infinite-scroll%22%2C%22stats%22%3A%22blog%3D166018295%26host%3Dnetology.ru%26v%3Dext%26j%3D1%3A8.2.4%26x_pagetype%3Dinfinite-click-jetpack%22%7D%7D' ) );
# 		//]]>
# 		</script>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TN84HZG" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script type="text/javascript">
#    (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#    m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#    (window, document, "script", "https://cdn.jsdelivr.net/npm/yandex-metrica-watch/tag.js", "ym");
#
#    ym(5240992, "init", {
#         clickmap:true,
#         trackLinks:true,
#         accurateTrackBounce:true,
#         webvisor:true,
#         ecommerce:"dataLayer"
#    });
# </script>
# <noscript><div><img alt="mc pixel" src="https://mc.yandex.ru/watch/5240992" style="position:absolute; left:-9999px;"/></div></noscript>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-22225928-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-22225928-1', {
#     'custom_map': {
#       'dimension3': 'client_id'
#     }
#   });
# </script>
# <script src="https://netology.ru/blog/wp-content/plugins/jetpack/_inc/build/infinite-scroll/infinity.min.js?ver=4.0.0" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var rmp_frontend = {"admin_ajax":"https:\/\/netology.ru\/blog\/wp-admin\/admin-ajax.php","postID":"30796","noVotes":"","cookie":"\u0412\u044b \u0443\u0436\u0435 \u0433\u043e\u043b\u043e\u0441\u043e\u0432\u0430\u043b\u0438 :)","afterVote":"","notShowRating":"1","social":"1","feedback":"1","cookieDisable":"1","emptyFeedback":"Please insert your feedback in the box above!","hoverTexts":"1","preventAccidental":"1","grecaptcha":"1","siteKey":"","votingPriv":"1","loggedIn":"","positiveThreshold":"2","ajaxLoad":"1","nonce":"92d7d8c349"};
# /* ]]> */
# </script>
# <script src="https://netology.ru/blog/wp-content/plugins/rate-my-post/public/js/rate-my-post.js?ver=3.3.4" type="text/javascript"></script>
# <script src="https://netology.ru/blog/wp-includes/js/mediaelement/wp-mediaelement.min.js?ver=5.2.12" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var screenReaderText = {"expand":"Expand child menu","collapse":"Collapse child menu"};
# /* ]]> */
# </script>
# <script src="https://netology.ru/blog/wp-content/themes/aquene-child-theme/assets/js/common.js?ver=1.2.9" type="text/javascript"></script>
# <script src="https://netology.ru/blog/wp-includes/js/wp-embed.min.js?ver=5.2.12" type="text/javascript"></script>
# <script type="text/javascript">
# 			jQuery.extend( infiniteScroll.settings.scripts, ["jquery-core","jquery-migrate","jquery","mediaelement-core","mediaelement-migrate","mediaelement","adaptive-js","loadmore","spin","jquery.spin","the-neverending-homepage","rate-my-post","wp-mediaelement","aquene-script","wp-embed"] );
# 			jQuery.extend( infiniteScroll.settings.styles, ["the-neverending-homepage","wp-block-library","rate-my-post","mediaelement","wp-mediaelement","aquene-style","adaptive-css","font-awesome","aquene-print-style","aquene-google-fonts","jetpack_css"] );
# 		</script><script>!function(){window.advanced_ads_ready_queue=window.advanced_ads_ready_queue||[],advanced_ads_ready_queue.push=window.advanced_ads_ready;for(var d=0,a=advanced_ads_ready_queue.length;d<a;d++)advanced_ads_ready(advanced_ads_ready_queue[d])}();</script><script async="async" defer="defer" src="https://stats.wp.com/e-202212.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	_stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:8.2.4',blog:'166018295',post:'0',tz:'3',srv:'netology.ru'} ]);
# 	_stq.push([ 'clickTrackerInit', '166018295', '0' ]);
# </script>
# <script type="text/javascript">
#     //Подписка на рассылку
#     var form = document.querySelector('#subscription');
#     form.addEventListener('submit', function(e){
#         e.preventDefault();
#         email = e.target.email.value;
#         $.ajax({
#           type: 'POST',
#           url: 'https://netology.ru/backend/api/contact_forms',
#           data: {
#             "email": email,
#             "phone": "",
#             "source": "blog",
#             "tags": ["pop-up_sub"]
#             }
#         }).done(function(response) {
#             if(response.contact_form_id) {
#                 var thanks = document.querySelector('#thanks-text');
#                 form.style.display = 'none';
#                 thanks.style.display = 'block';
#             } else {
#                 e.target.email.focus();
#             }
#         }).fail(function(response) {
#             e.target.email.focus();
#         });
#     });
#     var formDigest = document.querySelector('#subscription-digest');
#     formDigest.addEventListener('submit', function(e){
#         e.preventDefault();
#         email = e.target.email.value;
#         $.ajax({
#           type: 'POST',
#           url: 'https://netology.ru/backend/api/contact_forms',
#           data: {
#             "email": email,
#             "phone": "",
#             "source": "blog",
#             "tags": ["pop-up_sub"]
#             }
#         }).done(function(response) {
#             if(response.contact_form_id) {
#                 var thanksDigest = document.querySelector('#thanks-text-digest');
#                 formDigest.style.display = 'none';
#                 thanksDigest.style.display = 'block';
#             } else {
#                 e.target.email.focus();
#             }
#         }).fail(function(response) {
#             e.target.email.focus();
#         });
#     });
#
#
#     window.addEventListener('load', function() {
#         var currentYear = document.querySelector('.footer-left .current-year');
#         var rightColumns = document.querySelectorAll('.footer-right-column');
#         var searchBtn = document.querySelectorAll('.header-search-button');
#         var searchContainer = document.querySelector('.site-search-container');
#         var mobileMenuBtn = document.querySelectorAll('.mobile-menu-button');
#         var siteContainer = document.querySelector('.site.container');
#         var sideBarMenu = document.querySelector('.toggle-sidebar');
#         var sideBarOverlay = document.querySelector('.sidebar-overlay');
#         var closeSideBarBtn = document.getElementById('close-toggle-sidebar');
#
#         if (currentYear) {
#             currentYear.innerHTML = new Date(Date.now()).getFullYear();
#         }
#
#         if (window.innerWidth < 1024) {
#             if (rightColumns) {
#                 [].forEach.call(rightColumns, function(item) {
#                    item.addEventListener('click', function() {
#                       item.classList.toggle('active');
#                    });
#                 });
#             }
#         }
#
#         if (searchBtn) {
#             [].forEach.call(searchBtn, function(item) {
#                 item.addEventListener('click', function() {
#                    if (searchContainer) {
#                        searchContainer.classList.add('th-flex');
#                    }
#                 });
#             });
#         }
#
#         if (mobileMenuBtn) {
#             [].forEach.call(mobileMenuBtn, function (item) {
#                item.addEventListener('click', function() {
#                     if (siteContainer) {
#                         siteContainer.classList.add('to-right');
#                     }
#
#                     if (sideBarMenu) {
#                         sideBarMenu.classList.add('active');
#                     }
#
#                     if (sideBarOverlay) {
#                         sideBarOverlay.classList.add('active');
#                     }
#
#                     document.body.classList.add('active-toggle-sidebar');
#                });
#             });
#         }
#
#         if (sideBarOverlay) {
#             sideBarOverlay.addEventListener('click', function() {
#                 sideBarMenu.classList.remove('active');
#                 siteContainer.classList.remove('to-right');
#                 document.body.classList.remove('active-toggle-sidebar');
#                 sideBarOverlay.classList.remove('active');
#             });
#         }
#
#         if (closeSideBarBtn) {
#             closeSideBarBtn.addEventListener('click', function() {
#                 sideBarMenu.classList.remove('active');
#                 siteContainer.classList.remove('to-right');
#                 document.body.classList.remove('active-toggle-sidebar');
#                 sideBarOverlay.classList.remove('active');
#             });
#         }
#     });
#
#
#     ///////////////////////////////////
#     //Перенес из adaptive.js
#     var socials = [];
#     $('.socials').each(function () {
#     socials.push( $(this).clone().html() );
#     });
#
#     $('.wrap-header').before('<div class="mobile-panel">'
#       +'<a href="#navigator" class="mobile-btn"><span class="line"></span><span class="menu-text">Меню</span></a>'
#       +'<div class="m-logo"></div>'
#       +'<div class="m-search"><i class="icon-search"></i></div>'
#       +'<div id="navigator"><ul></ul></div>');
#
#     $('.filters').clone().prependTo('#navigator>ul');
#     $('.menu>a').clone().appendTo('#navigator>ul').wrap('<li class="menu__item mm-listitem"></li>');
#     $('.top-line__actions .fav').clone().appendTo('#navigator>ul').wrap('<li class="menu__item mm-listitem"></li>');
#     $( ".logo" ).clone().prependTo( ".m-logo" );
#
#     $('div#navigator').mmenu({
#       pageScroll: true,
#       extensions: [
#         'position-front'
#       ],
#       classNames: {
#         selected: 'active'
#       },
#       navbar: { add: false },
#       navbars: [
#         {
#             position: 'bottom',
#             content: ''+socials+''
#         }
#           ]
#     });
#     $('.actions__add').clone().insertBefore('.mm-listview');
#     $('<a href="#mm-0" aria-owns="mm-0" class="close-m">Закрыть</a>').prependTo('.mm-panels');
#
#     $(".m-search").click(function() {
# 		$('.search').slideToggle();
# 		$('.m-search').toggleClass('active');
# 	});
#     ////////Перенес из adaptive.js
#     ////////////////////////////
# </script>
# </body>
# </html>

# %%
# функция finda_all позволяет найти все указанные тег с нужными атрибутами (с вложениями), возвращает список
news = soup.find_all('div', class_='posts__item')
len(news)
# print(news)
# Out:
# [<div class="posts__item" id="post-30796">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-help-to-business" target="_blank">
# <img alt="Как помочь бизнесу в текущей ситуации: советы предпринимателей и экспертов" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обложка-мал_рубик.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/business" style="background:#5d00f5"><span style="background:#5d00f5">Предпринимательство</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-help-to-business" target="_blank">Как помочь бизнесу в текущей ситуации: советы предпринимателей и экспертов</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">23 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30777">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-finance-protection-in-crisis" target="_blank">
# <img alt="Как защитить финансы бизнеса в сложные времена" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обложка-мал_зонт.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/business" style="background:#5d00f5"><span style="background:#5d00f5">Предпринимательство</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-finance-protection-in-crisis" target="_blank">Как защитить финансы бизнеса в сложные времена</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">22 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30736">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-freelance-transformation" target="_blank">
# <img alt="Трансформация фриланса: почему независимые профессионалы объединяются в команды" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обл_главная_команда_shutterstock.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-freelance-transformation" target="_blank">Трансформация фриланса: почему независимые профессионалы объединяются в команды</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">22 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30719">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-deal-with-anxiety" target="_blank">
# <img alt="7 способов справиться с тревогой: советы от клинического психолога" src="https://netology.ru/blog/wp-content/uploads/2022/03/Справляемся-с-тревогой_превью.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-deal-with-anxiety" target="_blank">7 способов справиться с тревогой: советы от клинического психолога</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">18 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30687">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-tsifrovye-professii-b2g" target="_blank">
# <img alt="«Цифровые профессии»: как мы обучали IT в федеральном проекте" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обложка_мал_книжки.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/netologiya" style="background:#0066ff"><span style="background:#0066ff">Нетология</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-tsifrovye-professii-b2g" target="_blank">«Цифровые профессии»: как мы обучали IT в федеральном проекте</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">17 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30665">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-developers-types" target="_blank">
# <img alt="Каким программистом стать — рассказываем о популярных направлениях" src="https://netology.ru/blog/wp-content/uploads/2022/03/Каким-программистом-стать_превью.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-developers-types" target="_blank">Каким программистом стать — рассказываем о популярных направлениях</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">16 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30647">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-it-happens" target="_blank">
# <img alt="Как сообщить, что вы всё уронили: навыки поведения в ситуации, когда всё пошло не по плану" src="https://netology.ru/blog/wp-content/uploads/2022/03/Всё-не-по-плану_превью.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/how-to" style="background:#5d00f5"><span style="background:#5d00f5">Руководство</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-it-happens" target="_blank">Как сообщить, что вы всё уронили: навыки поведения в ситуации, когда всё пошло не по плану</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">15 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30621">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-data-science-digest" target="_blank">
# <img alt="Data Science-дайджест: что почитать, посмотреть и попробовать в марте 2022" src="https://netology.ru/blog/wp-content/uploads/2022/03/Data-Science-дайджест-март.png"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/books" style="background:#0066ff"><span style="background:#0066ff">Книжная полка</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-data-science-digest" target="_blank">Data Science-дайджест: что почитать, посмотреть и попробовать в марте 2022</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">14 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30603">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-self-help" target="_blank">
# <img alt="Как помочь себе в условиях неопределённости и стресса — советы психоаналитика" src="https://netology.ru/blog/wp-content/uploads/2022/03/Самоподдержка_превью.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-self-help" target="_blank">Как помочь себе в условиях неопределённости и стресса — советы психоаналитика</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">11 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30581">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-illustrator" target="_blank">
# <img alt="Кто такой иллюстратор, чем он занимается и сколько зарабатывает" src="https://netology.ru/blog/wp-content/uploads/2022/03/shubham-dhage-VEEqzwGwnpk-unsplash-1.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/professions" style="background:#4BD0A0"><span style="background:#4BD0A0">Современные профессии</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-illustrator" target="_blank">Кто такой иллюстратор, чем он занимается и сколько зарабатывает</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">10 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30543">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-kak-privlekat-it-vypusknikov" target="_blank">
# <img alt="Как работодателям привлекать начинающих IT-специалистов" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обложка_гл_зел.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-kak-privlekat-it-vypusknikov" target="_blank">Как работодателям привлекать начинающих IT-специалистов</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">10 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30535">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-unic" target="_blank">
# <img alt="«Я в безопасности»: бесплатный курс, который поможет пережить условия неопределённости" src="https://netology.ru/blog/wp-content/uploads/2022/03/Я-в-безопасности_превью.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/netologiya" style="background:#0066ff"><span style="background:#0066ff">Нетология</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-unic" target="_blank">«Я в безопасности»: бесплатный курс, который поможет пережить условия неопределённости</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">9 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30487">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-cjm-v-social-media" target="_blank">
# <img alt="Как Customer Journey Map помогает повысить продажи в Instagram" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обложка-мал_для-CJM.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/productivity" style="background:#4bd0a0"><span style="background:#4bd0a0">Продуктивность</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-cjm-v-social-media" target="_blank">Как Customer Journey Map помогает повысить продажи в Instagram</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">5 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30428">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-programming-languages" target="_blank">
# <img alt="Языки программирования: для чего нужны, какие популярны, как выбрать и с чего начать изучение" src="https://netology.ru/blog/wp-content/uploads/2022/03/Робот_превью.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-programming-languages" target="_blank">Языки программирования: для чего нужны, какие популярны, как выбрать и с чего начать изучение</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">3 марта 2022</div>
# </div>
# </div>, <div class="posts__item" id="post-30268">
# <div class="posts__img">
# <a href="https://netology.ru/blog/03-2022-copyright" target="_blank">
# <img alt="Как нарушение авторских прав влияет на самого автора и как предотвратить кражу контента" src="https://netology.ru/blog/wp-content/uploads/2022/03/Обложка_главная_стаканы.jpg"/>
# </a>
# <div class="tags">
# <a class="tags__item" href="/blog/category/what-is" style="background:#eb236b"><span style="background:#eb236b">Разобраться</span></a>
# </div>
# </div>
# <h2 class="posts__title"><a class="posts__link" href="https://netology.ru/blog/03-2022-copyright" target="_blank">Как нарушение авторских прав влияет на самого автора и как предотвратить кражу контента</a></h2>
# <div class="posts__txt">
# </div>
# <div class="posts__meta">
# <div class="posts__date">1 марта 2022</div>
# </div>
# </div>]

# %%
for el in news:
    title = el.find('a', 'posts__link').text
    print(title)
    link = el.find('a', 'posts__link').get('href')
    print(link)
    date = el.find('div', 'posts__date').text
    print(date)
    category = el.find('a', 'tags__item').text
    print(category)
    print()
# Out:
# Как помочь бизнесу в текущей ситуации: советы предпринимателей и экспертов
# https://netology.ru/blog/03-2022-help-to-business
# 23 марта 2022
# Предпринимательство
#
# Как защитить финансы бизнеса в сложные времена
# https://netology.ru/blog/03-2022-finance-protection-in-crisis
# 22 марта 2022
# Предпринимательство
#
# Трансформация фриланса: почему независимые профессионалы объединяются в команды
# https://netology.ru/blog/03-2022-freelance-transformation
# 22 марта 2022
# Разобраться
#
# 7 способов справиться с тревогой: советы от клинического психолога
# https://netology.ru/blog/03-2022-deal-with-anxiety
# 18 марта 2022
# Разобраться
#
# «Цифровые профессии»: как мы обучали IT в федеральном проекте
# https://netology.ru/blog/03-2022-tsifrovye-professii-b2g
# 17 марта 2022
# Нетология
#
# Каким программистом стать — рассказываем о популярных направлениях
# https://netology.ru/blog/03-2022-developers-types
# 16 марта 2022
# Разобраться
#
# Как сообщить, что вы всё уронили: навыки поведения в ситуации, когда всё пошло не по плану
# https://netology.ru/blog/03-2022-it-happens
# 15 марта 2022
# Руководство
#
# Data Science-дайджест: что почитать, посмотреть и попробовать в марте 2022
# https://netology.ru/blog/03-2022-data-science-digest
# 14 марта 2022
# Книжная полка
#
# Как помочь себе в условиях неопределённости и стресса — советы психоаналитика
# https://netology.ru/blog/03-2022-self-help
# 11 марта 2022
# Разобраться
#
# Кто такой иллюстратор, чем он занимается и сколько зарабатывает
# https://netology.ru/blog/03-2022-illustrator
# 10 марта 2022
# Современные профессии
#
# Как работодателям привлекать начинающих IT-специалистов
# https://netology.ru/blog/03-2022-kak-privlekat-it-vypusknikov
# 10 марта 2022
# Разобраться
#
# «Я в безопасности»: бесплатный курс, который поможет пережить условия неопределённости
# https://netology.ru/blog/03-2022-unic
# 9 марта 2022
# Нетология
#
# Как Customer Journey Map помогает повысить продажи в Instagram
# https://netology.ru/blog/03-2022-cjm-v-social-media
# 5 марта 2022
# Продуктивность
#
# Языки программирования: для чего нужны, какие популярны, как выбрать и с чего начать изучение
# https://netology.ru/blog/03-2022-programming-languages
# 3 марта 2022
# Разобраться
#
# Как нарушение авторских прав влияет на самого автора и как предотвратить кражу контента
# https://netology.ru/blog/03-2022-copyright
# 1 марта 2022
# Разобраться

# %% [markdown]
# Напишем функцию на основе всех предыдущих действий, которая будет возвращать датафрейм с датой, заголовком, категорией и ссылкой на полный текст поста

# %%
def get_netology_blog_posts():
    url = 'https://netology.ru/blog/'
    req = requests.get(url).text
    soup = BeautifulSoup(req)

    news = soup.find_all('div', class_='posts__item')

    netology_blog = pd.DataFrame()

    for el in news:
        title = el.find('a', 'posts__link').text
        link = el.find('a', 'posts__link').get('href')
        date = el.find('div', 'posts__date').text
        category = el.find('a', 'tags__item').text
        row = {'date': date, 'title': title, 'link': link, 'category':category}
        netology_blog = pd.concat([netology_blog, pd.DataFrame([row])]) 
    return netology_blog.reset_index(drop=True)

get_netology_blog_posts()
# Out:
#              date                                              title  \
# 0   23 марта 2022  Как помочь бизнесу в текущей ситуации: советы ...
# 1   22 марта 2022     Как защитить финансы бизнеса в сложные времена
# 2   22 марта 2022  Трансформация фриланса: почему независимые про...
# 3   18 марта 2022  7 способов справиться с тревогой: советы от кл...
# 4   17 марта 2022  «Цифровые профессии»: как мы обучали IT в феде...
# 5   16 марта 2022  Каким программистом стать — рассказываем о поп...
# 6   15 марта 2022  Как сообщить, что вы всё уронили: навыки повед...
# 7   14 марта 2022  Data Science-дайджест: что почитать, посмотрет...
# 8   11 марта 2022  Как помочь себе в условиях неопределённости и ...
# 9   10 марта 2022  Кто такой иллюстратор, чем он занимается и ско...
# 10  10 марта 2022  Как работодателям привлекать начинающих IT-спе...
# 11   9 марта 2022  «Я в безопасности»: бесплатный курс, который п...
# 12   5 марта 2022  Как Customer Journey Map помогает повысить про...
# 13   3 марта 2022  Языки программирования: для чего нужны, какие ...
# 14   1 марта 2022  Как нарушение авторских прав влияет на самого ...
#
#                                                  link               category
# 0   https://netology.ru/blog/03-2022-help-to-business    Предпринимательство
# 1   https://netology.ru/blog/03-2022-finance-prote...    Предпринимательство
# 2   https://netology.ru/blog/03-2022-freelance-tra...            Разобраться
# 3   https://netology.ru/blog/03-2022-deal-with-anx...            Разобраться
# 4   https://netology.ru/blog/03-2022-tsifrovye-pro...              Нетология
# 5   https://netology.ru/blog/03-2022-developers-types            Разобраться
# 6         https://netology.ru/blog/03-2022-it-happens            Руководство
# 7   https://netology.ru/blog/03-2022-data-science-...          Книжная полка
# 8          https://netology.ru/blog/03-2022-self-help            Разобраться
# 9        https://netology.ru/blog/03-2022-illustrator  Современные профессии
# 10  https://netology.ru/blog/03-2022-kak-privlekat...            Разобраться
# 11              https://netology.ru/blog/03-2022-unic              Нетология
# 12  https://netology.ru/blog/03-2022-cjm-v-social-...         Продуктивность
# 13  https://netology.ru/blog/03-2022-programming-l...            Разобраться
# 14         https://netology.ru/blog/03-2022-copyright            Разобраться

# %% [markdown]
# А теперь поработаем поиском по сайту

# %%
# cформируем поисковый запрос, обратите внимание на его формат
URL = 'https://netology.ru/blog/?s=python'

# %%
req = requests.get(URL)
req.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru-RU" prefix="og: https://ogp.me/ns#">\n<head>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<link rel="profile" href="https://gmpg.org/xfn/11">\n<title>python | Медиа Нетологии</title>\n\n<meta name="robots" content="max-image-preview:large" />\n<link rel="canonical" href="https://netology.ru/blog?s=python" />\n<link rel="next" href="https://netology.ru/blog/page/2?s=python" />\n\n<link rel="preload" href="https://netology.ru/blog/wp-content/plugins/rate-my-post/public/css/fonts/ratemypost.ttf" type="font/ttf" as="font" crossorigin="anonymous">\n\n<script data-cfasync="false" data-pagespeed-no-defer type="text/javascript">//<![CDATA[\n\tvar gtm4wp_datalayer_name = "dataLayer";\n\tvar dataLayer = dataLayer || [];\n//]]>\n</script>\n<link rel=\'dns-prefetch\' href=\'//netology.ru\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Медиа Нетологии &raquo; Лента" href="https://netology.ru/blog/feed" />\n<link rel="alternate" type="application/rss+xml" title="Медиа Нетологии &raquo; Лента комментариев" href="https://netology.ru/blog/comments/feed" />\n<link rel="alternate" type="application/rss+xml" title="Медиа Нетологии &raquo; Лента результатов поиска &laquo;python&raquo;" href="https://netology.ru/blog/search/python/feed/rss2/" />\n<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/netology.ru\\/blog\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=5.2.12"}};\n\t\t\t!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])?!1:!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);\n\t\t</script>\n<script id="netol-ready">\n\t\t\twindow.advanced_ads_ready=function(e,a){a=a||"complete";var d=function(e){return"interactive"===a?"loading"!==e:"complete"===e};d(document.readyState)?e():document.addEventListener("readystatechange",(function(a){d(a.target.readyState)&&e()}),{once:"interactive"===a})},window.advanced_ads_re ...

# %% [markdown]
# В функцию get можно передавать параметры и заголовки запроса в виде словаря

# %%
# в request можно передать параметры запроса и заголовки (headers) в виде словарей. 
URL = 'https://netology.ru/blog/'
params = {
    's': 'python'
}
headers = {
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Mobile Safari/537.36'
}

req = requests.get(URL, params=params, headers=headers)

req.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru-RU" prefix="og: https://ogp.me/ns#">\n<head>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<link rel="profile" href="https://gmpg.org/xfn/11">\n<title>python | Медиа Нетологии</title>\n\n<meta name="robots" content="max-image-preview:large" />\n<link rel="canonical" href="https://netology.ru/blog?s=python" />\n<link rel="next" href="https://netology.ru/blog/page/2?s=python" />\n\n<link rel="preload" href="https://netology.ru/blog/wp-content/plugins/rate-my-post/public/css/fonts/ratemypost.ttf" type="font/ttf" as="font" crossorigin="anonymous">\n\n<script data-cfasync="false" data-pagespeed-no-defer type="text/javascript">//<![CDATA[\n\tvar gtm4wp_datalayer_name = "dataLayer";\n\tvar dataLayer = dataLayer || [];\n//]]>\n</script>\n<link rel=\'dns-prefetch\' href=\'//netology.ru\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Медиа Нетологии &raquo; Лента" href="https://netology.ru/blog/feed" />\n<link rel="alternate" type="application/rss+xml" title="Медиа Нетологии &raquo; Лента комментариев" href="https://netology.ru/blog/comments/feed" />\n<link rel="alternate" type="application/rss+xml" title="Медиа Нетологии &raquo; Лента результатов поиска &laquo;python&raquo;" href="https://netology.ru/blog/search/python/feed/rss2/" />\n<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/netology.ru\\/blog\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=5.2.12"}};\n\t\t\t!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])?!1:!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);\n\t\t</script>\n<script id="netol-ready">\n\t\t\twindow.advanced_ads_ready=function(e,a){a=a||"complete";var d=function(e){return"interactive"===a?"loading"!==e:"complete"===e};d(document.readyState)?e():document.addEventListener("readystatechange",(function(a){d(a.target.readyState)&&e()}),{once:"interactive"===a})},window.advanced_ads_re ...

# %%
soup = BeautifulSoup(req.text)
articles = soup.find_all('article', class_='status-publish')
len(articles)
# Out:
# 6

# %%
netology_blog = pd.DataFrame()
for article in articles:
    title = article.find('h2', class_='entry-title').text
    link = article.find('h2', class_='entry-title').find('a').get('href')
    date = article.find('span', class_='posted-on').text.strip()
    category = article.find('div', class_='entry-cats').text
    row = {'date': date, 'title': title, 'link': link, 'category':category}
    netology_blog = pd.concat([netology_blog, pd.DataFrame([row])]) 
netology_blog
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-2ae1a87cb1c1> in <module>()
#       4     link = article.find('h2', class_='entry-title').find('a').get('href')
#       5     date = article.find('span', class_='posted-on').text.strip()
# ----> 6     category = article.find('div', class_='entry-cats').text
#       7     row = {'date': date, 'title': title, 'link': link, 'category':category}
#       8     netology_blog = pd.concat([netology_blog, pd.DataFrame([row])])
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
netology_blog = pd.DataFrame()
for article in articles:
    title = article.find('h2', class_='entry-title').text
    link = article.find('h2', class_='entry-title').find('a').get('href')
    date = article.find('span', class_='posted-on').text.strip()
    if article.find('div', class_='entry-cats'):
        category = article.find('div', class_='entry-cats').text
    else:
        category = 'Новость'
    row = {'date': date, 'title': title, 'link': link, 'category':category}
    netology_blog = pd.concat([netology_blog, pd.DataFrame([row])]) 
netology_blog
# Out:
#               date                                              title  \
# 0  12 октября 2021  Python занял первое место в рейтинге языков пр...
# 0     31 июля 2019       С чего начать изучение Python: 3 первых шага
# 0    15 марта 2019  С чего начать изучение Python: книги для начин...
# 0   16 января 2019  Как перейти в Machine learning, если знаешь Py...
# 0   14 января 2019  Создание модели распознавания лиц с использова...
# 0  30 декабря 2016        Как парсить данные с HTML-страниц на Python
#
#                                                 link               category
# 0    https://netology.ru/blog/news/12-10-2021-python                Новость
# 0  https://netology.ru/blog/07-2019-python-3-perv...  Современные профессии
# 0  https://netology.ru/blog/03-2019-python-knigi-...          Книжная полка
# 0  https://netology.ru/blog/2019-01-machine-learn...                Карьера
# 0  https://netology.ru/blog/2019-01-modeli-raspoz...            Руководство
# 0            https://netology.ru/blog/parsing-python            Руководство

# %% [markdown]
# А что если хотим собрать не только начальную выдачу, но и другие страницы? Изучам запросы при соответствующих действиях на сайте

# %%
# адрес для отправки запроса
url = 'https://netology.ru/blog/?infinity=scrolling'

# %%
# параметры для отправки запроса
params = {
    'page': 1,
    'query_args[s]': 'python'
}

# %%
# здесь мы используем post запрос
res = requests.post(url, params=params)
res.text
# Out:
# '{"type":"success","html":"\\n<article id=\\"post-3192\\" class=\\"post-3192 post type-post status-publish format-standard has-post-thumbnail hentry category-professions tag-dev\\">\\n\\t<a class=\\"thumb-link\\" href=\\"https:\\/\\/netology.ru\\/blog\\/07-2019-python-3-pervykh-shaga\\"><span role=\\"img\\" aria-label=\\"\\" class=\\"featured-image has-background-cover has-animation\\" style=\\"background-image: url(\'https:\\/\\/netology.ru\\/blog\\/wp-content\\/uploads\\/2020\\/05\\/222joshua-coleman-unsplash-980x460.jpg\');\\"><\\/span><\\/a>\\t<div class=\\"hentry-inner\\">\\n        <span class=\\"posted-on\\">\\n            <a href=\\"https:\\/\\/netology.ru\\/blog\\/07-2019-python-3-pervykh-shaga\\" rel=\\"bookmark\\">31 \\u0438\\u044e\\u043b\\u044f 2019<\\/a>\\n        <\\/span>\\n        <header class=\\"entry-header primary-font\\">\\n\\t\\t<div class=\\"entry-cats\\"><a href=\\"https:\\/\\/netology.ru\\/blog\\/category\\/professions\\" rel=\\"category tag\\">\\u0421\\u043e\\u0432\\u0440\\u0435\\u043c\\u0435\\u043d\\u043d\\u044b\\u0435 \\u043f\\u0440\\u043e\\u0444\\u0435\\u0441\\u0441\\u0438\\u0438<\\/a><\\/div><h2 class=\\"entry-title\\"><a href=\\"https:\\/\\/netology.ru\\/blog\\/07-2019-python-3-pervykh-shaga\\" rel=\\"bookmark\\">\\u0421 \\u0447\\u0435\\u0433\\u043e \\u043d\\u0430\\u0447\\u0430\\u0442\\u044c \\u0438\\u0437\\u0443\\u0447\\u0435\\u043d\\u0438\\u0435 Python: 3 \\u043f\\u0435\\u0440\\u0432\\u044b\\u0445 \\u0448\\u0430\\u0433\\u0430<\\/a><\\/h2>\\t\\t<\\/header><!-- .entry-header -->\\n\\n\\t\\t<footer class=\\"entry-footer clear\\">\\n<!--\\t\\t\\t-->\\t\\t<\\/footer><!-- .entry-footer -->\\n\\t<\\/div><!-- .hentry-inner -->\\n<\\/article><!-- #post-## -->\\n\\n<article id=\\"post-1971\\" class=\\"post-1971 post type-post status-publish format-standard has-post-thumbnail hentry category-books tag-dev\\">\\n\\t<a class=\\"thumb-link\\" href=\\"https:\\/\\/netology.ru\\/blog\\/03-2019-python-knigi-novichkam\\"><span role=\\"img\\" aria-label=\\"\\" class=\\"featured-image has-background-cover has-animation\\" style=\\"background-image: url(\'https:\\/\\/netology.ru\\/blog\\/wp-content\\/uploads\\/2019\\/09\\/6411-980x448.jpg\');\\"><\\/span><\\/a>\\t<div class=\\"hentry-inner\\">\\n        <span class=\\"posted-on\\">\\n            <a href=\\"https:\\/\\/netology.ru\\/blog\\/03-2019-python-knigi-novichkam\\" rel=\\"bookmark\\">15 \\u043c\\u0430\\u0440\\u0442\\u0430 2019<\\/a>\\n        <\\/span>\\n        <header class=\\"entry-header primary-font\\">\\n\\t\\t<div class=\\"entry-cats\\"><a href=\\"https:\\/\\/netology.ru\\/blog\\/category\\/books\\" rel=\\"category tag\\">\\u041a\\u043d\\u0438\\u0436\\u043d\\u0430\\u044f \\u043f\\u043e\\u043b\\u043a\\u0430<\\/a><\\/div><h2 class=\\"entry-title\\"><a href=\\"https:\\/\\/netology.ru\\/blog\\/03-2019-python-knigi-novichkam\\" rel=\\"bookmark\\">\\u0421 \\u0447\\u0435\\u0433\\u043e \\u043d\\u0430\\u0447\\u0430\\u0442\\u044c \\u0438\\u0437\\u0443\\u0447\\u0435\\u043d\\u0438\\u0435 Python: \\u043a\\u043d\\u0438\\u0433\\u0438 \\u0434\\u043b\\u044f \\u043d\\u0430\\u0447\\u0438\\u043d\\u0430\\u044e\\u0449\\u0438\\u0445<\\/a><\\/h2>\\t\\t<\\/header><!-- .entry-header -->\\n\\n\\t\\t<footer class=\\"entry-footer clear\\">\\n<!--\\t\\t\\t-->\\t\\t<\\/footer><!-- .entry-footer -->\\n\\t<\\/div><!-- .hentry-inner -->\\n<\\/article><!-- #post-## -->\\n\\n<article id=\\"post-1934\\" class=\\"post-1934 post type-post status-publish format-standard has-post-thumbnail hentry category-career tag-ds tag-dev\\">\\n\\t<a class=\\"thumb-link\\" href=\\"https:\\/\\/netology.ru\\/blog\\/2019-01-machine-learning-python\\"><span role=\\"img\\" aria-label=\\"\\" class=\\"featured-image has-background-cover has-animation\\" style=\\"background-image: url(\'https:\\/\\/netology.ru\\/blog\\/wp-content\\/uploads\\/2019\\/09\\/6325-980x448.jpg\');\\"><\\/span><\\/a>\\t<div class=\\"hentry-inner\\">\\n        <span class=\\"posted-on\\">\\n            <a href=\\"https:\\/\\/netology.ru\ ...

# %%
soup = BeautifulSoup(res.json()['html']) # извлекаем из ответа html-разметку
articles = soup.find_all('article', class_='status-publish')

netology_blog = pd.DataFrame()
for article in articles:
    title = article.find('h2', class_='entry-title').text
    link = article.find('h2', class_='entry-title').find('a').get('href')
    date = article.find('span', class_='posted-on').text.strip()
    if article.find('div', class_='entry-cats'):
        category = article.find('div', class_='entry-cats').text
    else:
        category = 'Новость'    
    row = {'date': date, 'title': title, 'link': link, 'category':category}
    netology_blog = pd.concat([netology_blog, pd.DataFrame([row])]) 
netology_blog
# Out:
#               date                                              title  \
# 0     31 июля 2019       С чего начать изучение Python: 3 первых шага
# 0    15 марта 2019  С чего начать изучение Python: книги для начин...
# 0   16 января 2019  Как перейти в Machine learning, если знаешь Py...
# 0   14 января 2019  Создание модели распознавания лиц с использова...
# 0  30 декабря 2016        Как парсить данные с HTML-страниц на Python
# 0  14 октября 2016  Что такое Python: чем он хорош, где пригодится...
#
#                                                 link               category
# 0  https://netology.ru/blog/07-2019-python-3-perv...  Современные профессии
# 0  https://netology.ru/blog/03-2019-python-knigi-...          Книжная полка
# 0  https://netology.ru/blog/2019-01-machine-learn...                Карьера
# 0  https://netology.ru/blog/2019-01-modeli-raspoz...            Руководство
# 0            https://netology.ru/blog/parsing-python            Руководство
# 0                    https://netology.ru/blog/python            Разобраться

# %%
# напишем функцию по предыдущему коду
def get_posts_from_blog():
    url = 'https://netology.ru/blog/?infinity=scrolling'    
    params = {
        'page': 1,
        'query_args[s]': 'python'
    }
    res = requests.post(url, params=params)

    soup = BeautifulSoup(res.json()['html']) 
    articles = soup.find_all('article', class_='status-publish')

    netology_blog = pd.DataFrame()
    for article in articles:
        title = article.find('h2', class_='entry-title').text
        link = article.find('h2', class_='entry-title').find('a').get('href')
        date = article.find('span', class_='posted-on').text.strip()
        if article.find('div', class_='entry-cats'):
            category = article.find('div', class_='entry-cats').text
        else:
            category = 'Новость'        
        row = {'date': date, 'title': title, 'link': link, 'category':category}
        netology_blog = pd.concat([netology_blog, pd.DataFrame([row])]) 
    return netology_blog.reset_index(drop=True)

get_posts_from_blog()
# Out:
#               date                                              title  \
# 0     31 июля 2019       С чего начать изучение Python: 3 первых шага
# 1    15 марта 2019  С чего начать изучение Python: книги для начин...
# 2   16 января 2019  Как перейти в Machine learning, если знаешь Py...
# 3   14 января 2019  Создание модели распознавания лиц с использова...
# 4  30 декабря 2016        Как парсить данные с HTML-страниц на Python
# 5  14 октября 2016  Что такое Python: чем он хорош, где пригодится...
#
#                                                 link               category
# 0  https://netology.ru/blog/07-2019-python-3-perv...  Современные профессии
# 1  https://netology.ru/blog/03-2019-python-knigi-...          Книжная полка
# 2  https://netology.ru/blog/2019-01-machine-learn...                Карьера
# 3  https://netology.ru/blog/2019-01-modeli-raspoz...            Руководство
# 4            https://netology.ru/blog/parsing-python            Руководство
# 5                    https://netology.ru/blog/python            Разобраться

# %% [markdown]
# А как извлечь посты с нескольких страниц?

# %%
# импортируем библиотеку для задержки исполнения кода
import time

def get_posts_from_blog(pages):
    url = 'https://netology.ru/blog/?infinity=scrolling'    
    params = {
        'query_args[s]': 'python'
    }

    netology_blog = pd.DataFrame() 
    # добавим цикл с перебором страниц
    for page in range(1, pages+1):
        params['page'] = page
        res = requests.post(url, params=params)
        time.sleep(0.33)
        soup = BeautifulSoup(res.json()['html']) 
        articles = soup.find_all('article', class_='status-publish')

        for article in articles:
            title = article.find('h2', class_='entry-title').text
            link = article.find('h2', class_='entry-title').find('a').get('href')
            date = article.find('span', class_='posted-on').text.strip()
            category = article.find('div', class_='entry-cats').text
            row = {'date': date, 'title': title, 'link': link, 'category':category}
            netology_blog = pd.concat([netology_blog, pd.DataFrame([row])]) 

    return netology_blog.reset_index(drop=True)

get_posts_from_blog(5)
# Out:
#                date                                              title  \
# 0      31 июля 2019       С чего начать изучение Python: 3 первых шага
# 1     15 марта 2019  С чего начать изучение Python: книги для начин...
# 2    16 января 2019  Как перейти в Machine learning, если знаешь Py...
# 3    14 января 2019  Создание модели распознавания лиц с использова...
# 4   30 декабря 2016        Как парсить данные с HTML-страниц на Python
# 5   14 октября 2016  Что такое Python: чем он хорош, где пригодится...
# 6     16 марта 2022  Каким программистом стать — рассказываем о поп...
# 7     14 марта 2022  Data Science-дайджест: что почитать, посмотрет...
# 8      3 марта 2022  Языки программирования: для чего нужны, какие ...
# 9    8 февраля 2022  Где нас нет: что заставляет ИТ-специалистов пе...
# 10   4 февраля 2022  10 вопросов дата-журналисту: почему в результа...
# 11   20 января 2022  Что такое SexTech и почему это не только секс-...
# 12   18 января 2022  Где в России айтишнику жить хорошо: статистика...
# 13   12 января 2022  Data Science-дайджест: что почитать, посмотрет...
# 14  23 декабря 2021  «Если вы выучили один язык программирования, т...
# 15  21 декабря 2021    Ключевые технологические тренды Web Summit 2021
# 16  10 декабря 2021  10 вопросов аналитику: как выглядят большие да...
# 17    8 ноября 2021  Как определить качество онлайн-курса и создать...
# 18  26 октября 2021  От «стесняшки» до «архитектора»: какими бывают...
# 19  19 октября 2021  Data Science-дайджест: что почитать, посмотрет...
# 20  9 сентября 2021  Как сменить профессию во взрослом возрасте: ва...
# 21  30 августа 2021  Фейковые новости: чем опасны, как появляются и...
# 22  10 августа 2021  Как выбрать онлайн-курс: форматы, критерии, во...
# 23     14 июля 2021  Дизайн-мышление, умение питчить и железные буб...
# 24      9 июля 2021  Монстры аналитики: как случайная беседа в Клаб...
# 25      4 июня 2021  Это всё Россия: чем живёт ИТ- и диджитал-тусов...
# 26      2 июня 2021  Мир обсуждает NFT: рассказываем, что это за то...
# 27       4 мая 2021  Что почитать в мае: 12 книг для руководителей,...
# 28   14 апреля 2021  Data Science–дайджест: полезные статьи, сервис...
# 29    2 апреля 2021  Системный аналитик: что делает, сколько получа...
#
#                                                  link  \
# 0   https://netology.ru/blog/07-2019-python-3-perv...
# 1   https://netology.ru/blog/03-2019-python-knigi-...
# 2   https://netology.ru/blog/2019-01-machine-learn...
# 3   https://netology.ru/blog/2019-01-modeli-raspoz...
# 4             https://netology.ru/blog/parsing-python
# 5                     https://netology.ru/blog/python
# 6   https://netology.ru/blog/03-2022-developers-types
# 7   https://netology.ru/blog/03-2022-data-science-...
# 8   https://netology.ru/blog/03-2022-programming-l...
# 9            https://netology.ru/blog/02-2022-it-move
# 10  https://netology.ru/blog/02-2022-data-journali...
# 11   https://netology.ru/blog/01-2022-what-is-sextech
# 12            https://netology.ru/blog/01-2022-it-geo
# 13  https://netology.ru/blog/01-2022-data-science-...
# 14   https://netology.ru/blog/12-2021-change-language
# 15  https://netology.ru/blog/12-2021-web-summit-tr...
# 16     https://netology.ru/blog/12-2021-analytics-faq
# 17  https://netology.ru/blog/11-2021-kachestvo-onl...
# 18            https://netology.ru/blog/10-2021-devops
# 19         https://netology.ru/blog/10-2021-ds-digest
# 20  https://netology.ru/blog/09-2021-kak-smenit-pr...
# 21         https://netology.ru/blog/08-2021-fake-news
# 22  https://netology.ru/blog/08-2021-vybrat-online...
# 23      https://netology.ru/blog/07-2021-productsense
# 24  https://netology.ru/blog/07-2021-monsters-and-...
# 25  https://netology.ru/blog/06-2021-eto-vsyo-rossiya
# 26       https://netology.ru/blog/06-2021-what-is-nft
# 27  https://netology.ru/blog/05-2021-chto-pochitat...
# 28  https://netology.ru/blog/04-2021-data-science-...
# 29  https://netology.ru/blog/04-2021-sistemniy-ana...
#
#                          category
# 0           Современные профессии
# 1                   Книжная полка
# 2                         Карьера
# 3                     Руководство
# 4                     Руководство
# 5                     Разобраться
# 6                     Разобраться
# 7                   Книжная полка
# 8                     Разобраться
# 9                     Разобраться
# 10          Современные профессии
# 11                    Разобраться
# 12                    Разобраться
# 13                  Книжная полка
# 14                    Личный опыт
# 15                    Разобраться
# 16          Современные профессии
# 17                      Нетология
# 18          Современные профессии
# 19                  Книжная полка
# 20      Карьера Научиться учиться
# 21                    Разобраться
# 22              Научиться учиться
# 23                        Карьера
# 24  Карьера Личный опыт Нетология
# 25              Нетология События
# 26                    Разобраться
# 27                  Книжная полка
# 28                  Книжная полка
# 29          Современные профессии

# %% [markdown]
# А если хотим добавить в датафрейм полные тексты всех постов?

# %%
blog_posts = get_posts_from_blog(5)

def add_full_text(posts_df):
    i = 0
    for el in posts_df['link']:
        print(el)
        req = requests.get(el).text
        time.sleep(0.33)
        soup = BeautifulSoup(req)
        full_text = soup.find('div', class_='entry-content').text.strip()
        posts_df.loc[i, 'text'] = full_text
        i += 1
    return posts_df

add_full_text(blog_posts)
# Out:
# https://netology.ru/blog/07-2019-python-3-pervykh-shaga
# https://netology.ru/blog/03-2019-python-knigi-novichkam
# https://netology.ru/blog/2019-01-machine-learning-python
# https://netology.ru/blog/2019-01-modeli-raspoznavaniya-lic
# https://netology.ru/blog/parsing-python
# https://netology.ru/blog/python
# https://netology.ru/blog/03-2022-developers-types
# https://netology.ru/blog/03-2022-data-science-digest
# https://netology.ru/blog/03-2022-programming-languages
# https://netology.ru/blog/02-2022-it-move
# https://netology.ru/blog/02-2022-data-journalist-faq
# https://netology.ru/blog/01-2022-what-is-sextech
# https://netology.ru/blog/01-2022-it-geo
# https://netology.ru/blog/01-2022-data-science-digest
# https://netology.ru/blog/12-2021-change-language
# https://netology.ru/blog/12-2021-web-summit-trends
# https://netology.ru/blog/12-2021-analytics-faq
# https://netology.ru/blog/11-2021-kachestvo-online-kursov
# https://netology.ru/blog/10-2021-devops
# https://netology.ru/blog/10-2021-ds-digest
# https://netology.ru/blog/09-2021-kak-smenit-professiyu
# https://netology.ru/blog/08-2021-fake-news
# https://netology.ru/blog/08-2021-vybrat-online-kurs
# https://netology.ru/blog/07-2021-productsense
# https://netology.ru/blog/07-2021-monsters-and-analytics
# https://netology.ru/blog/06-2021-eto-vsyo-rossiya
# https://netology.ru/blog/06-2021-what-is-nft
# https://netology.ru/blog/05-2021-chto-pochitat-v-mae
# https://netology.ru/blog/04-2021-data-science-daijest
# https://netology.ru/blog/04-2021-sistemniy-analitik
#                date                                              title  \
# 0      31 июля 2019       С чего начать изучение Python: 3 первых шага
# 1     15 марта 2019  С чего начать изучение Python: книги для начин...
# 2    16 января 2019  Как перейти в Machine learning, если знаешь Py...
# 3    14 января 2019  Создание модели распознавания лиц с использова...
# 4   30 декабря 2016        Как парсить данные с HTML-страниц на Python
# 5   14 октября 2016  Что такое Python: чем он хорош, где пригодится...
# 6     16 марта 2022  Каким программистом стать — рассказываем о поп...
# 7     14 марта 2022  Data Science-дайджест: что почитать, посмотрет...
# 8      3 марта 2022  Языки программирования: для чего нужны, какие ...
# 9    8 февраля 2022  Где нас нет: что заставляет ИТ-специалистов пе...
# 10   4 февраля 2022  10 вопросов дата-журналисту: почему в результа...
# 11   20 января 2022  Что такое SexTech и почему это не только секс-...
# 12   18 января 2022  Где в России айтишнику жить хорошо: статистика...
# 13   12 января 2022  Data Science-дайджест: что почитать, посмотрет...
# 14  23 декабря 2021  «Если вы выучили один язык программирования, т...
# 15  21 декабря 2021    Ключевые технологические тренды Web Summit 2021
# 16  10 декабря 2021  10 вопросов аналитику: как выглядят большие да...
# 17    8 ноября 2021  Как определить качество онлайн-курса и создать...
# 18  26 октября 2021  От «стесняшки» до «архитектора»: какими бывают...
# 19  19 октября 2021  Data Science-дайджест: что почитать, посмотрет...
# 20  9 сентября 2021  Как сменить профессию во взрослом возрасте: ва...
# 21  30 августа 2021  Фейковые новости: чем опасны, как появляются и...
# 22  10 августа 2021  Как выбрать онлайн-курс: форматы, критерии, во...
# 23     14 июля 2021  Дизайн-мышление, умение питчить и железные буб...
# 24      9 июля 2021  Монстры аналитики: как случайная беседа в Клаб...
# 25      4 июня 2021  Это всё Россия: чем живёт ИТ- и диджитал-тусов...
# 26      2 июня 2021  Мир обсуждает NFT: рассказываем, что это за то...
# 27       4 мая 2021  Что почитать в мае: 12 книг для руководителей,...
# 28   14 апреля 2021  Data Science–дайджест: полезные статьи, сервис...
# 29    2 апреля 2021  Системный аналитик: что делает, сколько получа...
#
#                                                  link  \
# 0   https://netology.ru/blog/07-2019-python-3-perv...
# 1   https://netology.ru/blog/03-2019-python-knigi-...
# 2   https://netology.ru/blog/2019-01-machine-learn...
# 3   https://netology.ru/blog/2019-01-modeli-raspoz...
# 4             https://netology.ru/blog/parsing-python
# 5                     https://netology.ru/blog/python
# 6   https://netology.ru/blog/03-2022-developers-types
# 7   https://netology.ru/blog/03-2022-data-science-...
# 8   https://netology.ru/blog/03-2022-programming-l...
# 9            https://netology.ru/blog/02-2022-it-move
# 10  https://netology.ru/blog/02-2022-data-journali...
# 11   https://netology.ru/blog/01-2022-what-is-sextech
# 12            https://netology.ru/blog/01-2022-it-geo
# 13  https://netology.ru/blog/01-2022-data-science-...
# 14   https://netology.ru/blog/12-2021-change-language
# 15  https://netology.ru/blog/12-2021-web-summit-tr...
# 16     https://netology.ru/blog/12-2021-analytics-faq
# 17  https://netology.ru/blog/11-2021-kachestvo-onl...
# 18            https://netology.ru/blog/10-2021-devops
# 19         https://netology.ru/blog/10-2021-ds-digest
# 20  https://netology.ru/blog/09-2021-kak-smenit-pr...
# 21         https://netology.ru/blog/08-2021-fake-news
# 22  https://netology.ru/blog/08-2021-vybrat-online...
# 23      https://netology.ru/blog/07-2021-productsense
# 24  https://netology.ru/blog/07-2021-monsters-and-...
# 25  https://netology.ru/blog/06-2021-eto-vsyo-rossiya
# 26       https://netology.ru/blog/06-2021-what-is-nft
# 27  https://netology.ru/blog/05-2021-chto-pochitat...
# 28  https://netology.ru/blog/04-2021-data-science-...
# 29  https://netology.ru/blog/04-2021-sistemniy-ana...
#
#                          category  \
# 0           Современные профессии
# 1                   Книжная полка
# 2                         Карьера
# 3                     Руководство
# 4                     Руководство
# 5                     Разобраться
# 6                     Разобраться
# 7                   Книжная полка
# 8                     Разобраться
# 9                     Разобраться
# 10          Современные профессии
# 11                    Разобраться
# 12                    Разобраться
# 13                  Книжная полка
# 14                    Личный опыт
# 15                    Разобраться
# 16          Современные профессии
# 17                      Нетология
# 18          Современные профессии
# 19                  Книжная полка
# 20      Карьера Научиться учиться
# 21                    Разобраться
# 22              Научиться учиться
# 23                        Карьера
# 24  Карьера Личный опыт Нетология
# 25              Нетология События
# 26                    Разобраться
# 27                  Книжная полка
# 28                  Книжная полка
# 29          Современные профессии
#
#                                                  text
# 0   В прошлой статье мы рассказали, почему стоит и...
# 1   Нетология рассказала, с какой книги начать изу...
# 2   Директор разработки и data scientist ДомКлик.р...
# 3   Адаптировали статью Файзана Шайха о том, как с...
# 4   Руководитель проектов Дмитрий Мирошниченко рас...
# 5   Python — самый быстрорастущий язык программиро...
# 6   Разработка — широкая сфера, в которой заняты с...
# 7   Рассказываем, сколько времени понадобится на в...
# 8   По данным SuperJob, за год потребность в разра...
# 9   Недавно мы рассказали о том, что не только в М...
# 10  В мире накопилось большое количество данных, к...
# 11  SexTech — это больше, чем Tinder, VR-порно и с...
# 12  Рынок труда ИТ в России развивается неравномер...
# 13  Год только начался, а мы уже собрали всё самое...
# 14  Сегодня наш гость — Андрей Борю, разработчик и...
# 15  Web Summit — самая крупная технологическая кон...
# 16  Аналитика данных — направление, о котором гово...
# 17  В онлайн-образовании принято ориентироваться н...
# 18  DevOps-инженеры — люди, которые создают и конт...
# 19  Играем в «Камень-ножницы-бумага» всей Россией,...
# 20  В последние десять лет появилось всё больше во...
# 21  Новости — неотъемлемая часть нашей жизни. Инфо...
# 22  Обучение на неподходящем курсе может обернутьс...
# 23  В апреле прошла конференция ProductSense — кру...
# 24  24 февраля, на волне популярности эфиров в Кла...
# 25  Есть стереотип: жизнь бьёт ключом только в Мос...
# 26  В последние месяцы аббревиатура NFT мелькает в...
# 27  Длинные майские праздники позволят посвятить в...
# 28  В свежей подборке статей и видеороликов по Dat...
# 29  Системный аналитик помогает оптимизировать и а...

# %% [markdown]
# Напишем скрипт, который будет собирать новости с сайта Коммерсанта

# %%
URL = 'https://www.kommersant.ru/search/results'
params = {
    'search_query': 'python'
}

# %%
res = requests.get(URL, params)

# %%
res.text
# Out:
# '<!DOCTYPE html>\r\n<html class="no-js" lang="ru">\r\n<head>\r\n    <title>Коммерсантъ: последние новости России и мира</title>\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1" />\r\n    <meta charset="utf-8" />\r\n\r\n    <meta name="format-detection" content="telephone=no" />\r\n    <meta name="title" content="Коммерсантъ: последние новости России и мира" />\r\n    <meta name="description" content="Актуальные новости, объективный анализ и эксклюзивные комментарии о важнейших событиях и трендах" />\r\n    <meta name="keywords" content="Новости,Политика,Экономика,Бизнес,Финансы,Дело,Биржа,Рынок,Акции,Прогнозы,Критика,Интервью,Рейтинги,Документы,Деньги,Власть,Автопилот,Тематические страницы,Первые лица,Деловые новости,Мировая практика,Культура,Спорт,Weekend,Астрологический прогноз,Погода мира,Курсы валют ЦБ РФ" />\r\n\r\n    <meta name="yandex-verification" content="50df68945a519dbd" />\r\n\r\n    \r\n<meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n\r\n\r\n\r\n        <meta property="fb:app_id" content="324580610921010" />\r\n        <meta property="og:type" content="website" />\r\n        <meta property="og:url" content="https://www.kommersant.ru" />\r\n        <meta property="og:title" content="Коммерсантъ: последние новости России и мира" />\r\n        <meta property="og:description" content="Актуальные новости, объективный анализ и эксклюзивные комментарии о важнейших событиях и трендах" />\r\n        <meta property="og:image" content="https://im.kommersant.ru/ContentFlex/images/logo.png" />\r\n        <link rel="image_src" href="https://im.kommersant.ru/CorpPics/logo200.jpg" />\r\n\r\n    \r\n<!-- common css -->\r\n    <script>\r\n        document.documentElement.classList.remove(\'no-js\');\r\n    </script>\r\n\r\n    <link rel="preconnect" href="https://use.typekit.net/" crossorigin>\r\n    <link rel="preload" as="style" href="https://use.typekit.net/mfw2heq.css">\r\n    <link rel="stylesheet" media="print" onload="this.onload=null;this.removeAttribute(\'media\');" href="https://use.typekit.net/mfw2heq.css">\r\n    <noscript>\r\n        <link rel="stylesheet" href="https://use.typekit.net/mfw2heq.css">\r\n    </noscript>\r\n\r\n    <link href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonCss.css?2203241811280000" rel="stylesheet">\r\n    <link rel="preload" href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonDeferCss.css?2203241811280000" as="style" onload="this.onload=null;this.rel=\'stylesheet\'">\r\n    <noscript><link rel="stylesheet" href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonDeferCss.css?2203241811280000"></noscript>\r\n<!-- common css end -->\r\n\r\n\r\n    \r\n\r\n    \r\n<link rel="apple-touch-icon" sizes="57x57" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-57.png">\r\n<link rel="apple-touch-icon" sizes="60x60" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-60.png">\r\n<link rel="apple-touch-icon" sizes="72x72" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-72.png">\r\n<link rel="apple-touch-icon" sizes="76x76" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-76.png">\r\n<link rel="apple-touch-icon" sizes="114x114" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-114.png">\r\n<link rel="apple-touch-icon" sizes="120x120" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-120.png">\r\n<link rel="apple-touch-icon" sizes="144x144" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-144.png">\r\n<link rel="apple-touch-icon" sizes="152x152" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-152.png">\r\n<link rel="apple-touch-icon" sizes="180x180" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-180.png">\r\n<link rel="icon" type="i ...

# %%
soup = BeautifulSoup(res.text)
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="ru">
# <head>
# <title>Коммерсантъ: последние новости России и мира</title>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="Коммерсантъ: последние новости России и мира" name="title"/>
# <meta content="Актуальные новости, объективный анализ и эксклюзивные комментарии о важнейших событиях и трендах" name="description"/>
# <meta content="Новости,Политика,Экономика,Бизнес,Финансы,Дело,Биржа,Рынок,Акции,Прогнозы,Критика,Интервью,Рейтинги,Документы,Деньги,Власть,Автопилот,Тематические страницы,Первые лица,Деловые новости,Мировая практика,Культура,Спорт,Weekend,Астрологический прогноз,Погода мира,Курсы валют ЦБ РФ" name="keywords"/>
# <meta content="50df68945a519dbd" name="yandex-verification"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="324580610921010" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.kommersant.ru" property="og:url"/>
# <meta content="Коммерсантъ: последние новости России и мира" property="og:title"/>
# <meta content="Актуальные новости, объективный анализ и эксклюзивные комментарии о важнейших событиях и трендах" property="og:description"/>
# <meta content="https://im.kommersant.ru/ContentFlex/images/logo.png" property="og:image"/>
# <link href="https://im.kommersant.ru/CorpPics/logo200.jpg" rel="image_src"/>
# <!-- common css -->
# <script>
#         document.documentElement.classList.remove('no-js');
#     </script>
# <link crossorigin="" href="https://use.typekit.net/" rel="preconnect"/>
# <link as="style" href="https://use.typekit.net/mfw2heq.css" rel="preload"/>
# <link href="https://use.typekit.net/mfw2heq.css" media="print" onload="this.onload=null;this.removeAttribute('media');" rel="stylesheet"/>
# <noscript>
# <link href="https://use.typekit.net/mfw2heq.css" rel="stylesheet"/>
# </noscript>
# <link href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonCss.css?2203241811280000" rel="stylesheet"/>
# <link as="style" href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonDeferCss.css?2203241811280000" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <noscript><link href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonDeferCss.css?2203241811280000" rel="stylesheet"/></noscript>
# <!-- common css end -->
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/favicon.svg" rel="icon" type="image/svg+xml"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/favicon-32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/android-chrome-192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/favicon-16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#2d89ef" name="msapplication-TileColor"/>
# <meta content="https://im.kommersant.ru/ContentFlex/images/favicons2020/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <!-- search page head css -->
# <link href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.search.css?2203241811280000" rel="stylesheet"/>
# <!-- search page head css end -->
# <script>
#                 window.puids = {
#                     'puid1': '0',
#                     'puid2': '',
#                     'puid3': '',
#                     'puid4': 'i0',
#                     'puid5': '999'
#                 };
#     </script>
# <!-- common scripts -->
# <link href="https://im.kommersant.ru" rel="preconnect"/>
# <script src="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonJS.js?2203241811280000"></script>
# <script async="" src="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.pushPopup.js?2203241811280000"></script>
# <script defer="" src="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.pollJS.js?2203241811280000"></script>
# <script>
#     kommersant.antiCache.jsMark = 'https://im.kommersant.ru/ContentFlex/js/jquery.mark.min.js?2109231134459908';
#     kommersant.antiCache.jsJqueryValidate = 'https://im.kommersant.ru/ContentFlex/js/jquery.validate.min.js?2109231134459908';
#     kommersant.antiCache.jsNanoScroller = 'https://im.kommersant.ru/ContentFlex/js/jquery.nanoscroller.min.js?2109231134459908';
#     kommersant.antiCache.jsScrollMagic = 'https://im.kommersant.ru/ContentFlex/js/scrollmagic/ScrollMagic.min.js?2109231134459908';
#     kommersant.antiCache.jsHighmapsCisDisputed = 'https://im.kommersant.ru/ContentFlex/js/highmaps/cis-disputed.js?2109231134459908';
#     kommersant.antiCache.jsCharts = 'https://im.kommersant.ru/ContentFlex/js/charts.new2021.js?2202141653190991';
#     kommersant.antiCache.jsWidgets = 'https://im.kommersant.ru/ContentFlex/js/widgets.new2021.js?2201111747301991';
#     kommersant.antiCache.jsHighmapsWorldDisputed = 'https://im.kommersant.ru/ContentFlex/js/highmaps/world-disputed.js?2109231134459908';
#     kommersant.vicons.add('https://im.kommersant.ru/ContentFlex/ajax/vicons/common.new2021.html?2110202128418612', { cache: true });
#
# </script>
# <script>
#     window.__storage__ = window.__storage__ || {}
#     window.__storage__.lentaBanners = {
#         businessAnnounce: "&lt;!--AdFox START--&gt; &lt;!--kommersant--&gt; &lt;!--Площадка: Kommersant_redesign / 0Десктоп / 3й анонс в ленте--&gt; &lt;!--Категория: &lt;не задана&gt;--&gt; &lt;!--Тип баннера: 3й анонс в ленте--&gt; &lt;!--197--&gt;  &lt;div id=&quot;adfox_162799247887971226&quot;&gt;&lt;/div&gt; &lt;script&gt;     window.yaContextCb.push(()=&gt;{         Ya.adfoxCode.create({             ownerId: 1092,         containerId: &#39;adfox_162799247887971226&#39;,             params: Object.assign({                 p1: &#39;cqgxq&#39;,             p2: &#39;hhrr&#39;,          }, window.puids || {})        }, [&#39;desktop&#39;,&#39;phone&#39;,&#39;tablet&#39;], {         tabletWidth: 1197.99,         phoneWidth: 1197.99,         isAutoReloads: false     })   })  &lt;/script&gt; ",
#         twoAnnounces: [{"Id":542,"ProfileId":1,"Position":1,"Type":1,"DocId":5270798,"Title":"«Абсолютное соблюдение закона о банкротстве позволило сохранить Антипинский НПЗ»","Subtitle":"Конкурсный управляющий Константин Сичевой","Link":null,"IsSelfLink":false,"ImageSrc":null,"Enabled":true,"Category":"Промо"},{"Id":532,"ProfileId":1,"Position":2,"Type":1,"DocId":5251891,"Title":"Свой дом — тихая гавань: клубный дом «Досфлота, 10»","Subtitle":"Жить в красивом доме с видом на воду — лучший способ переждать эпоху перемен","Link":null,"IsSelfLink":false,"ImageSrc":"https://im.kommersant.ru/Issues.photo/Partners_Docs/2022/03/11/KMO_111307_42154_1_t218_214845.jpg","Enabled":true,"Category":"Промо"}]
#     }
# </script>
# <script async="" src="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.lentaVue.js?2203241811280000"></script>
# <!-- common scripts end-->
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# <script>
#         window.kommersant.backend.adv = {
#             180: '\u003c!--AdFox START--\u003e\r\n\u003c!--kommersant--\u003e\r\n\u003c!--Площадка: Kommersant_redesign / 0Десктоп / БА2--\u003e\r\n\u003c!--Категория: \u003cне задана\u003e--\u003e\r\n\u003c!--Тип баннера: СБА_БА--\u003e\r\n\u003c!--180--\u003e\r\n\u003cdiv id=\"adfox_161707797679975629\"\u003e\u003c/div\u003e\r\n\u003cscript\u003e\r\n    window.yaContextCb.push(()=\u003e{\r\n        Ya.adfoxCode.createScroll({\r\n        ownerId: 1092,\r\n        containerId: \u0027adfox_161707797679975629\u0027,\r\n        params: Object.assign({\r\n            p1: \u0027corsv\u0027,\r\n            p2: \u0027hedx\u0027,\r\n           }, window.puids || {})\r\n       }, [\u0027desktop\u0027], {\r\n        tabletWidth: 1197.99,\r\n        phoneWidth: 1197.99,\r\n        isAutoReloads: false\r\n     })\r\n  })\r\n\u003c/script\u003e',
#         };
#     </script>
# </head>
# <body>
# <svg aria-hidden="true" style="display: none" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><symbol id="vicon-main_logo" viewbox="0 0 158 20"><path d="M40 4h5v12h-4V9l-2.8 7h-1.9c-.2-.7-.5-.6-2.3-7v7h-4V4h5.5l1.8 6.6L40 4zm13.3 6.6L51.5 4H46v12h4V9c1.8 6.4 2 6.3 2.3 7h2c0-.3 2.6-6.6 2.7-7v7h4V4h-5l-2.7 6.6zM15.7 0H10L5 5.6V0H0v16h5v-5.1l1.5-1.6 4 6.7h6L9.8 6l5.8-6zM29 10c0 4-2.5 6.3-6.6 6.3-4 0-6.5-2.3-6.5-6 0-3.9 2.4-6.2 6.5-6.2 4 0 6.6 2.4 6.6 6zm-4.3 0c0-1.8-1-3.1-2.2-3.1-1.7 0-2.3 1.6-2.3 3.2 0 3 1.4 3.4 2.2 3.4 1 0 2.3-.6 2.3-3.4zM158 12c0 3-2.7 4-5 4h-7V7h-3V4h7v4h3c3.5 0 5 2.1 5 4zm-4 0c0-1.2-1.1-1.4-2.1-1.4h-1.7v2.7h1.7c1 0 2.1-.1 2.1-1.3zm-24-5h4v9h4V7h4V4h-12v3zm-14 7.5c0 .6 0 1 .6 1.5h-4.7l-.2-1.5-.3.2a5.8 5.8 0 01-4.3 1.6c-2 0-4-.9-4-3.4 0-3.1 3-3.5 5.3-3.8 1.7-.2 3-.3 3-1.4 0-.7-.6-1.2-1.7-1.2-1 0-1.6.4-1.8 1.2h-4.2c.2-2.4 2.2-3.6 6.3-3.6 5.4 0 6 2 6 4.8v5.6zm-4.5-4l-.3.2a7 7 0 01-1.6.5c-1.1.2-2.1.4-2.1 1.6 0 .7.7 1.2 1.7 1.2 2 0 2.3-1.6 2.3-3.1v-.3zM125 9h-4V4h-4v12h4v-4h4v4h4V4h-4v5zm-36 1.1c0 4.6-2.4 5.9-5 5.9a5 5 0 01-2-.5c-.3-.2-1-.5-1.6-1.1L80 14v6h-4V4h4v2c.6-1.4 2.6-1.9 3.9-1.9 3.7 0 5 3.2 5 6zm-4.3 0c0-1.8-.9-3-2.3-3-1.3 0-2.1 1.3-2.1 3 0 1.8.8 3 2.1 3 1.4 0 2.3-1.2 2.3-3zm-18.4.9v.3c0 1.4 1.1 2.5 2.6 2.5a2 2 0 001.7-.8h4.2c-1.2 3-4.7 3.3-6.2 3.3-4 0-6.6-2.4-6.6-6s2.7-6.2 6.5-6.2c4.2 0 6.8 2.6 6.8 6.9h-9zm0-2H71V9c0-1.3-1-2.3-2.3-2.3-1.5 0-2.4.9-2.4 2.3V9zM96 13.6c-1.4 0-2.3-1.1-2.3-3.2C93.7 7.5 95 7 96 7c1 0 1.8.7 2 1.7h4.3C101.9 5.8 99.6 4 96 4c-4 0-6.6 2.4-6.6 6.2 0 3.6 2.6 6 6.6 6 2.1 0 5.6-.6 6.3-4.3H98c-.3 1-1 1.5-2 1.5z"></path></symbol><symbol id="vicon-search" viewbox="0 0 30 30"><path d="M24.55 22.97l-5-5.01a8.09 8.09 0 10-1.58 1.58l5 5.02c.53.52 1.3.6 1.74.15s.37-1.21-.16-1.74zM13.1 18.68a5.6 5.6 0 110-11.2 5.6 5.6 0 010 11.2z"></path></symbol><symbol id="vicon-burger" viewbox="0 0 30 30"><path d="M25 6v4H5V6h20zM5 17h20v-4H5v4zm0 7h20v-4H5v4z"></path></symbol><symbol id="vicon-regions" viewbox="0 0 30 30"><path d="M15.1 5C19 5 22 8 22 11.9c0 4.3-6.9 13.1-6.9 13.1s-6.8-8.7-6.8-13.1C8.3 8 11.3 5 15 5zm0 10a3.1 3.1 0 100-6.2 3.1 3.1 0 000 6.2z"></path></symbol><symbol id="vicon-fm" viewbox="0 0 30 30"><path d="M24.25 16.21L20 18.34v-6.68l4.25 2.13c1 .5 1 1.92 0 2.42zm-9.7-4.96l1.2 4.56 1.18-4.56h2.24l-12.2-6.1C6.05 4.68 5 5.34 5 6.34v4.9h5.8v1.61H7.34v1.31h2.94v1.52H7.35v3.06H5v4.9c0 1 1.06 1.66 1.96 1.2l12.21-6.1H18.1v-5.72l-1.49 5.72h-1.73l-1.48-5.72v5.72h-1.92v-7.5h3.08z"></path></symbol><symbol id="vicon-rarrow" viewbox=" 0 0 30 30"><path d="M9.22.33c.85-.59 2.02-.38 2.61.47l9.38 13.48c.45.66.44 1.54-.03 2.18l-9.37 12.77a1.87 1.87 0 11-3.03-2.22L17.36 15 8.76 2.94a1.88 1.88 0 01.46-2.6z"></path></symbol></svg>
# <div id="counters-top" style="position: absolute; visibility: hidden">
# <script>
# (function () {
# 	window.kommersantAnalytics = {
# 		adblock: '',
# 		rubrics: '',
# 		publishing: '',
# 		themes: '',
# 		themegroups: '',
# 		authors: '',
# 		audio: 'No',
# 		liveinternet: ''
# 	};
# 	var advad = new Image();
# 	advad.onload = function () {
# 		window.kommersantAnalytics.adblock = 'No';
# 	};
# 	advad.onerror = function () {
# 		window.kommersantAnalytics.adblock = 'Yes';
# 	};
# 	advad.src = 'https://im.kommersant.ru/ContentFlex/images/adv.gif';
# })();
# </script>
# <!-- Google Tag Manager -->
# <!--<noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-K37VX3" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>-->
# <script>
# // 	(function (w, d, s, l, i) {
# // 		w[l] = w[l] || []; w[l].push({ 'gtm.start':
# // new Date().getTime(), event: 'gtm.js'
# // 		}); var f = d.getElementsByTagName(s)[0],
# // j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
# // '//www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# // 	})(window, document, 'script', 'dataLayer', 'GTM-K37VX3');
# </script>
# <!-- End Google Tag Manager -->
# <!-- Kommersant -->
# <script>
# function counterKommersant() {
# //new Image().src = '//www.kommersant.ru/headerfooter/counterA?p=0&ref=' + escape(document.referrer) + '&rnd=' + Math.floor(Math.random() * 1000000000);
# }
# function counterKommersantRead() {
#
# }
# counterKommersant();
# counterKommersantRead();
# </script>
# <noscript>
# </noscript>
# <!-- /Kommersant -->
# <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "84394", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
# if (d.getElementById(id)) return;
# var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
# ts.src = (d.location.protocol == "https:" ? "https:" : "http:") + "//top-fwz1.mail.ru/js/code.js";
# var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
# if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img alt="" src="//top-fwz1.mail.ru/counter?id=84394;js=na" style="border:0;position:absolute;left:-9999px;"/>
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
# <!--LiveInternet counter-->
# <script>
# function counterLiveInternet() {
# 	new Image().src = "//counter.yadro.ru/hit" + (window.kommersantAnalytics.liveinternet ? ";" + window.kommersantAnalytics.liveinternet : "") + "?r" + escape(document.referrer) + ((typeof (screen) == "undefined") ? "" : ";s" + screen.width + "*" + screen.height + "*" + (screen.colorDepth ? screen.colorDepth : screen.pixelDepth)) + ";u" + escape(document.URL) + ";h" + escape(document.title.substring(0, 80)) + ";" + Math.random();
# }
# counterLiveInternet();
# </script>
# <noscript>
# <img alt="" height="1" src="//counter.yadro.ru/hit" width="1"/>
# </noscript>
# <!--/LiveInternet-->
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
# 	var yaParams = {
#
# };
# </script>
# <script type="text/javascript">
#    (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#    m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#    (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#    ym(153166, "init", {
#         clickmap:true,
#         trackLinks:true,
#         accurateTrackBounce:true,
#         trackHash:true,
#         params: yaParams
#    });
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/153166" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <img id="advad" src="https://im.kommersant.ru/ContentFlex/images/adv.gif" style="display: none"/>
# <script>
# (function (i, s, o, g, r, a, m) {
# i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
# (i[r].q = i[r].q || []).push(arguments)
# }, i[r].l = 1 * new Date(); a = s.createElement(o),
# m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
# })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
# ga('create', 'UA-875277-5', 'kommersant.ru');
#
# ga('set', 'dimension6', 'No');
# if (window.kommersantAnalytics.adblock) {
# 	ga('set', 'dimension3', window.kommersantAnalytics.adblock || null);
# }
# ga('set', 'page', window.location.pathname + window.location.search + window.location.hash);
# ga('send', 'pageview');
# </script>
# <!-- tns-counter.ru -->
# <script>
# function counterTns() {
# new Image().src = '//www.tns-counter.ru/V13a***R>' + document.referrer.replace(/\*/g, '%2a') + '*kommersant_ru/ru/CP1251/tmsec=komm_junk/' + Math.floor(Math.random() * 900000000 + 100000000);
# }
# counterTns();
# </script>
# <noscript>
# <img alt="" height="1" src="//www.tns-counter.ru/V13a****kommersant_ru/ru/CP1251/tmsec=komm_junk/" width="1"/>
# </noscript>
# <!--/tns-counter.ru -->
# </div>
# <script>
# function countersUpdate() {
# 	counterKommersant();
# 	counterKommersantRead();
#
# 	try {
# 		_tmr.push({id: '84394', type: 'pageView', url: document.URL, start: (new Date()).getTime()});
# 	} catch (ignore) {}
#
# 	counterLiveInternet();
#
# 	(function () {
# 		var yaParams = {};
# 		window.kommersantAnalytics.rubrics && (yaParams.rubric = window.kommersantAnalytics.rubrics);
# 		window.kommersantAnalytics.publishing && (yaParams.publication = window.kommersantAnalytics.publishing);
# 		window.kommersantAnalytics.themes && (yaParams.theme = window.kommersantAnalytics.themes);
# 		window.kommersantAnalytics.themegroups && (yaParams.maintheme = window.kommersantAnalytics.themegroups);
# 		try {
# 			ym(153166, 'params', yaParams);
# 			ym(153166, 'hit', window.location.pathname + window.location.search + window.location.hash, {
# 				params: yaParams
# 			});
# 		} catch (ignore) {}
# 	})();
#
# 	(function () {
# 		try {
# 			ga('set', 'page', window.location.pathname + window.location.search + window.location.hash);
# 			ga('set', 'dimension1', window.kommersantAnalytics.rubrics || null);
# 			ga('set', 'dimension2', window.kommersantAnalytics.publishing || null);
# 			ga('set', 'dimension4', window.kommersantAnalytics.themes || null);
# 			ga('set', 'dimension5', window.kommersantAnalytics.themegroups || null);
# 			ga('set', 'dimension8', window.kommersantAnalytics.authors || null);
# 			ga('set', 'dimension6', window.kommersantAnalytics.audio || null);
# 			ga('set', 'dimension3', window.kommersantAnalytics.adblock || null);
# 			ga('send', 'pageview');
# 		} catch (ignore) {}
# 	})();
#
# 	counterTns();
#
# 	try {
# 		counterIo();
# 	} catch (ignore) {}
# }
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign / 0Десктоп / Fullscreen-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: Fullscreen_redesign_test-->
# <!--190-->
# <div id="adfox_160803209609717001"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_160803209609717001',
#         params: Object.assign({
#             p1: 'blnry',
#             p2: 'eurl'
#           }, window.puids || {})
#        }, ['desktop','phone','tablet'], {
#         tabletWidth: 1197.99,
#         phoneWidth: 1197.99,
#         isAutoReloads: false
#     })
#   })
#
# </script><!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / 0Десктоп / BackGround test-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: BackGround-->
# <!--185-->
# <div id="adfox_153864371043563488"></div>
# <script>
#
# window.yaContextCb.push(()=>{
#         Ya.adfoxCode.createScroll({
#
#         ownerId: 1092,
#         containerId: 'adfox_153864371043563488',
#         params: Object.assign({
#             p1: 'cbuhy',
#             p2: 'gbom',
#           }, window.puids || {}),
#          onRender: function () {$('.adfox-banner-background').after('<style>.adv3-2_140pxx1200px {display: none;}@media only screen and (min-width: 1200px) {body {padding-top: 250px;}.main_nav {max-width: 1180px;width: 100%;margin-left: auto;margin-right: auto;}.bg_cover {position: absolute;top: 250px;right: 0;left: 0;bottom: 0;background-color: #fff;width: 1180px;margin: 0 auto;}}</style><div class="bg_cover"></div>')}
#
#        }, ['desktop'], {
#           tabletWidth: 1197.99,
#           phoneWidth: 1197.99,
#       })
#   })
# </script> <input aria-hidden="true" aria-labeledby="site_menu" class="hide site_menu_trigger" hidden="" id="burger_trigger" type="checkbox"/>
# <div class="layout">
# <div class="adv_nest adv_nest--980x250_top hide_mobile">
# <div class="adv_dummy"><a href="/ad" target="_blank">Реклама в «Ъ» www.kommersant.ru/ad</a></div>
# <div class="adv_980x240">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign / 0Десктоп / BILB I (970_250) Перетяжка-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: BILBI_970_250-->
# <!--167-->
# <div id="adfox_160803211171647429"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_160803211171647429',
#         params: Object.assign({
#             p1: 'blnrl',
#             p2: 'eurc',
#             pk: 'оккупация%20украин%20донецк%20луганск%20бомб%20санкци%20днр%20лнр%20Донбасс%20военная',
#             pke: '1'
#         }, window.puids || {})
#     }, ['desktop'], {
#         tabletWidth: 1197.99,
#         phoneWidth: 1197.99,
#         isAutoReloads: false
#      })
#   })
#
# </script>
# </div>
# </div>
# <div class="adv_nest adv_nest--300x250_top hide_desktop">
# <div class="adv_dummy"><a href="/ad" target="_blank">Реклама в «Ъ» www.kommersant.ru/ad</a></div>
# <div class="adv_300x250_top">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Мобильный / BILB 300x250 I-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: 300x250-->
# <!--173-->
# <div id="adfox_1488194504651863"></div>
# <script>
#      window.yaContextCb.push(()=>{
#         Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1488194504651863',
#
#         params: Object.assign({
#             p1: 'bukwz',
#              p2: 'fibq',
#             pk: 'оккупация%20украин%20донецк%20луганск%20бомб%20санкци%20днр%20лнр%20Донбасс%20военная',
#             pke: '1'
#         }, window.puids || {})
#     }, ['phone','tablet'], {
#         tabletWidth: 1197.99,
#         phoneWidth: 1197.99,
#         isAutoReloads: false
#      })
#   })
#
# </script>
# </div>
# </div>
# </div>
# <header class="main_header">
# <div class="layout">
# <div class="main_header__content">
# <label class="main_header__item main_header__burger" for="burger_trigger" tabindex="0" title="Рубрики и разделы">
# <!-- <img src="i/burger.png" class="main_header__icon" alt="Рубрики и разделы"> -->
# <span class="vicon vicon--burger main_header__icon main_header__burger_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-burger" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="main_header__logo" href="/?from=logo">
# <svg aria-hidden="true" class="main_header__logo_img"><use xlink:href="#vicon-main_logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="vh">Коммерсантъ</span>
# </a>
# <div class="main_header__buttons">
# <span class="auth js-auth main_header__item hide_mobile">
# <a class="auth__profile" href="/lk/profile?from=header" title="Профиль">
# <span aria-hidden="true" class="vicon main_header__icon main_header__login_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-user" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="auth__login user-login" href="/LK/Login?from=header" title="Личный кабинет">
# <span aria-hidden="true" class="vicon main_header__icon main_header__login_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-enter" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </span>
# <a class="main_header__item main_header__item--regions hide_mobile js-navmenu-trigger" data-navmenu-class-active="main_header__item--active" data-navmenu-id="js-navmenu-regions" href="/regions" title="Регионы">
# <span class="main_header__pointer"></span>
# <span aria-hidden="true" class="vicon main_header__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-regions" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="ui-button main_header__item main_header__item--fm hide_mobile fm_announce" href="/fm/player?from=header" rel="nofollow" target="_blanc" title="Коммерсантъ FM">
# <span class="vh">Коммерсантъ FM</span>
# <span aria-hidden="true" class="vicon main_header__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-fm" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <form action="/search/results" class="main_header__item main_header__item--search" id="js-navsearch-form" method="get">
# <input name="places" type="hidden" value=""/>
# <input name="categories" type="hidden" value=""/>
# <input name="datestart" type="hidden" value="2021-03-24"/>
# <input name="dateend" type="hidden" value="2022-03-24"/>
# <input name="sort_type" type="hidden" value="1"/>
# <input name="regions" type="hidden" value=""/>
# <input name="results_count" type="hidden" value=""/>
# <input name="page" type="hidden" value="1"/>
# <input class="main_header__search_field" id="js-navsearch-query" name="search_query" placeholder="Поиск" type="search"/>
# <button class="ui-button vicon main_header__icon" id="js-navsearch-submit" title="Поиск" type="submit">
# <svg class="vicon__body">
# <use xlink:href="#vicon-search" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </button>
# </form>
# </div>
# </div>
# </div>
# </header>
# <section class="site_menu hide_while_loading" id="site_menu" itemscope="" itemtype="https://www.schema.org/SiteNavigationElement">
# <label class="site_menu__close_overlay" for="burger_trigger"><span class="vh">Закрыть меню</span></label>
# <div class="site_menu__lift">
# <div class="layout site_menu__body">
# <h4 class="site_menu__name vh" id="site_menu__name">
#                 Меню сайта
#             </h4>
# <div class="site_menu__header">
# <label class="site_menu__header_item site_menu__burger" for="burger_trigger" tabindex="0" title="Рубрики и разделы">
# <span class="vicon site_menu__icon site_menu__burger_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-burger" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="site_menu__logo" href="/?from=logo">
# <svg class="site_menu__logo_img"><use xlink:href="#vicon-main_logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </a>
# <label class="site_menu__header_item site_menu__close" for="burger_trigger" tabindex="0">
# <span class="site_menu__close_text">Закрыть</span>
# <span aria-hidden="true" class="vicon vicon--close site_menu__icon site_menu__close_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-close" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# </div>
# <div class="auth js-auth site_menu__list site_menu__list--big site_menu__list--auth hide_desktop">
# <a class="auth__profile" href="/lk/profile?from=burger" title="Профиль">
# <span aria-hidden="true" class="vicon site_menu__auth_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-user" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="auth__login user-login" href="/LK/Login?from=burger" title="Личный кабинет">
# <span aria-hidden="true" class="vicon site_menu__auth_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-enter" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="hide_desktop" data-navmenu-class-active="main_header__item--active" data-navmenu-id="js-navmenu-regions" href="/regions" title="Регионы">
# <span aria-hidden="true" class="vicon site_menu__auth_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-regions" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="hide_desktop" href="/fm/player?from=burger" rel="nofollow" target="_blanc" title="Коммерсантъ FM">
# <span aria-hidden="true" class="vicon site_menu__auth_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-fm" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </div>
# <ul class="site_menu__list site_menu__list--big">
# <li class="site_menu__item site_menu__item--big" itemprop="name">
# <a href="/redaction?from=burger" itemprop="url">Редакция</a>
# </li>
# <li class="site_menu__item site_menu__item--big" itemprop="name">
# <a href="/fm?from=burger" itemprop="url">Радио «Ъ FM»</a>
# </li>
# <li class="site_menu__item site_menu__item--big" itemprop="name">
# <a href="//rusfond.ru?from=burger" itemprop="url" target="_blank">Русфонд</a>
# <a href="//rusfond.ru?from=burger" target="_blank"><img alt="Русфонд" class="site_menu__rusfond_img" src="https://im.kommersant.ru/ContentFlex/images/redesign2020/rusfond_logo.png"/></a>
# </li>
# </ul>
# <ul class="site_menu__list">
# <li class="site_menu__item" itemprop="name">
# <a href="//bankruptcy.kommersant.ru?from=burger" itemprop="url" target="_blank">Банкротства</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/partnerprojects?from=burger" itemprop="url">Партнерские проекты</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="//www.kartoteka.ru?from=burger" itemprop="url" target="_blank">Картотека</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="//events.kommersant.ru?from=burger" itemprop="url" target="_blank">Конференции</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="//university.kommersant.ru?from=burger" itemprop="url" target="_blank">Университетъ</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/subscription?from=burger" itemprop="url">Подписка</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/ad?from=burger" itemprop="url">Реклама</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="https://photo.kommersant.ru/?from=burger" itemprop="url">Фотоагентство</a>
# </li>
# </ul>
# <ul class="site_menu__list">
# <li class="site_menu__item" itemprop="name">
# <a href="/daily?from=burger" itemprop="url">Газета</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/weekend?from=burger" itemprop="url">Weekend</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/apps?from=burger" itemprop="url">Приложения</a>
# </li>
# <li class="site_menu__item site" itemprop="name">
# <a href="/autopilot?from=burger" itemprop="url">Автопилот</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/nauka?from=burger" itemprop="url">Наука</a>
# </li>
# <li class="site_menu__item site_menu__item--indent" itemprop="name">
# <a href="/money?from=burger" itemprop="url">Деньги</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/regions?from=burger" itemprop="url">Регионы</a>
# </li>
# </ul>
# <ul class="site_menu__list">
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/3?from=burger" itemprop="url">Экономика</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/2?from=burger" itemprop="url">Политика</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/5?from=burger" itemprop="url">Мир</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/4?from=burger" itemprop="url">Бизнес</a>
# </li>
# <li class="site_menu__item site" itemprop="name">
# <a href="/finance?from=burger" itemprop="url">Финансы</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/41?from=burger" itemprop="url">Потребительский рынок</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/138?from=burger" itemprop="url">Телекоммуникации</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/7?from=burger" itemprop="url">Общество</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/6?from=burger" itemprop="url">Происшествия</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/8?from=burger" itemprop="url">Культура</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/9?from=burger" itemprop="url">Спорт</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/hitech?from=burger" itemprop="url">Hi-Tech</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/auto?from=burger" itemprop="url">Авто</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/style?from=burger" itemprop="url">Стиль</a>
# </li>
# </ul>
# <ul class="site_menu__list">
# <li class="site_menu__item" itemprop="name">
# <a href="/themes?from=burger" itemprop="url">Темы</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/theme/3155?from=burger" itemprop="url">Тенденции</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/specials?from=burger" itemprop="url">Мультимедиа</a>
# </li>
# <li class="site_menu__item site" itemprop="name">
# <a href="/theme/2590?from=burger" itemprop="url">Интервью</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/doc/3688126?from=burger" itemprop="url">Справочники</a>
# </li>
# <li class="site_menu__item site_menu__item--indent" itemprop="name">
# <a href="/ratings?from=burger" itemprop="url">Самое читаемое</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/lk/notification?from=burger" itemprop="url">E-mail рассылки</a>
# </li>
# </ul>
# </div>
# </div>
# </section>
# <div class="regions hide_while_loading hide_mobile">
# <div class="regions__menu js-navmenu-item" data-navmenu-class-active="regions__menu--active" id="js-navmenu-regions">
# <div class="layout">
# <div class="main">
# <div class="regions__body">
# <ul class="regions__list">
# <li class="regions__item">
# <a class="regions__link" href="/theme/3378">Москва</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/78">Санкт-Петербург</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/36">Воронеж</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/66">Екатеринбург</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/18">Ижевск</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/16">Казань</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/23">Краснодар</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/24">Красноярск</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/52">Нижний Новгород</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/54">Новосибирск</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/59">Пермь</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/61">Ростов-на-Дону</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/63">Самара</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/64">Саратов</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/2">Уфа</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/74">Челябинск</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/76">Ярославль</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="actual">
# <div class="layout">
# <div class="main">
# <div class="actual__body slider slider-actual">
# <div class="actual__nav_button actual__nav_button--prev slider-prev">
# <a class="actual__nav_button_link slider-link link" href="#">
# <span class="vicon vicon--larrow">
# <svg class="vicon__body">
# <use xlink:href="#vicon-rarrow" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="vh">Предыдущая страница</span>
# </a>
# </div>
# <ul class="actual__list slider-canvas">
# <li class="actual__item slider-item">
# <ul class="actual__money slider-actual-item">
# <li class="actual__money_item">
# <a class="no_decor slider-link actual__fall" href="/indices?from=actualno">$ 97,00</a>
# </li>
# <li class="actual__money_item">
# <a class="no_decor slider-link actual__fall" href="/indices?from=actualno">€ 106,80</a>
# </li>
# <li class="actual__money_item">
# <a class="no_decor slider-link actual__raise" href="/indices?from=actualno">IMOEX 2578,51</a>
# </li>
# </ul>
# <a class="actual__link slider-link slider-actual-item" href="https://www.kommersant.ru/theme/3423?from=actualno">Военная операция на Украине</a>
# <a class="actual__link slider-link slider-actual-item" href="/theme/2036?from=actualno">Санкции против России</a>
# <a class="actual__link slider-link slider-actual-item" href="/doc/5271644?from=actualno">Валютный прогноз</a>
# <a class="actual__link slider-link slider-actual-item" href="/theme/3304?from=actualno">Пандемия</a>
# <a class="actual__link slider-link slider-actual-item" href="/rubric/149?from=actualno">Эксклюзивы «Ъ»</a>
# <a class="actual__link slider-link slider-actual-item" href="/theme/943?from=actualno">Андрей Колесников о Владимире Путине</a>
# </li>
# </ul>
# <div class="actual__nav_button actual__nav_button--next slider-next">
# <a class="actual__nav_button_link slider-link link" href="#">
# <span class="vicon vicon--rarrow">
# <svg class="vicon__body">
# <use xlink:href="#vicon-rarrow" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="vh">Следующая страница</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <main>
# <div class="layout">
# <div class="search">
# <section class="main grid">
# <div class="grid-col grid-col-s3">
# <div class="service_menu">
# <div class="service_menu__item">
# <input class="hide js-toggle-input" id="search_rules" type="checkbox"/>
# <label class="ui-icon" for="search_rules">
# <span class="icon_text js-toggle-item" data-toggle-id="search_rules">
#                                         Правила поиска
#                                     </span>
# <span class="ui-rotate js-toggle-item" data-toggle-class-checked="ui-rotate_180" data-toggle-id="search_rules">
# <span class="service_menu__arrow vicon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-rarrow" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </span>
# </label>
# </div>
# </div>
# <div class="ui-collapse js-toggle-collapse js-toggle-item ui-collapse--hide" data-toggle-class-animated="ui-collapse--animated" data-toggle-class-checked="ui-collapse--show" data-toggle-class-unchecked="ui-collapse--hide" data-toggle-id="search_rules">
# <div class="service_panel doc">
# <p class="simple_page_section_name"><b>В качестве поисковых терминов можно использовать:</b></p>
# <ul>
# <li>отдельное слово;</li>
# <li>несколько слов, разделенных пробелами (поиск документов, включающих все слова).</li>
# </ul>
# <p class="simple_page_section_name"><b>Поиск производится:</b></p>
# <ul>
# <li>без учета строчных и прописных букв;</li>
# <li>игнорируя знаки пунктуации.</li>
# </ul>
# <p class="simple_page_section_name"><b>Дополнительные условия:</b></p>
# <ul>
# <li>в запрос могут быть включены операторы-связки (AND, OR, NOT) и оператор близости (NEAR);</li>
# <li>слова запроса могут иметь символ обобщения (*), но только в конце слова;</li>
# <li>слова при поиске интерпретируются с учетом словоформ.</li>
# <li>для поиска по точной форме запроса этот запрос нужно указать в кавычках.</li>
# </ul>
# <p class="simple_page_section_name"><b>Замечания:</b></p>
# <ul>
# <li>при использовании специальных символов (&amp;, |, ^, #, @, $, (, ), *) запрос следует взять в кавычки;</li>
# <li>для поиска слов, заключенных в кавычки, весь запрос следует также заключить в кавычки.</li>
# </ul>
# <p class="simple_page_section_name"><b>Пример запроса и результаты поиска:</b></p>
# <p class="doc__text">
# <b>Запрос:</b> "банк "Империал""<br/>
# <b>Результат:</b> Статьи, включающие фразу «банк "Империал"»<br/>
# </p>
# <p class="doc__text">
# <b>Запрос:</b> Курс and доллара<br/>
# <b>Результат:</b> Статьи, имеющие оба слова «курс», «доллара»<br/>
# </p>
# <p class="doc__text">
# <b>Запрос:</b> Курс or "доллар*" or "высок"<br/>
# <b>Результат:</b> Статьи, включающие одно из слов — «курс», «доллар», «доллара», «долларов», «долларовая», «высокого», «высокому» и т.д.<br/>
# </p>
# </div>
# </div>
# <header class="simple_page__header">
# <h1 class="simple_page__name">
#                                 Поиск
#                             </h1>
# </header>
# <form action="/search/results" class="doc ui-list js-search">
# <div class="ui-field_pack">
# <input class="ui-input ui-input--search" name="search_query" placeholder="Поиск" type="search" value="python"/>
# <button class="ui-button ui-button--standart ui-button--wide ui-button--smallest_vw_rgap" type="submit">Искать</button>
# <input class="vh js-toggle-input js-state-trigger" id="search_extend" type="checkbox"/>
# <label class="ui-button ui-button--standart ui-button--wide js-state-item" data-state-class-focus-visible="is_focused" data-state-id="search_extend" for="search_extend">
#             Расширенный поиск
#             <span class="vicon vicon--gull_down search__arrow">
# <svg class="vicon__body ui-rotate js-toggle-item" data-toggle-class-checked="ui-rotate_180" data-toggle-id="search_extend">
# <use xlink:href="#vicon-rarrow" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# </div>
# <section class="simple_page_section simple_page_section--no_margin js-search-settings">
# <h2 class="simple_page_section_name">Как сортировать?</h2>
# <div class="grid">
# <div class="grid-col grid-col-half">
# <p class="doc__text">
# <label>
# <input class="ui-radio js-search-radio" name="sort_type" type="radio" value="1"/>
# <span class="ui-text">по релевантности</span>
# </label>
# </p>
# </div>
# <div class="grid-col grid-col-half">
# <p class="doc__text">
# <label>
# <input checked="" class="ui-radio js-search-radio" name="sort_type" type="radio" value="0"/>
# <span class="ui-text">по дате</span>
# </label>
# </p>
# </div>
# </div>
# </section>
# <div class="ui-collapse js-toggle-collapse js-toggle-item ui-collapse--hide" data-toggle-class-animated="ui-collapse--animated" data-toggle-class-checked="ui-collapse--show" data-toggle-class-unchecked="ui-collapse--hide" data-toggle-id="search_extend">
# <section class="simple_page_section simple_page_section--no_margin">
# <h2 class="simple_page_section_name">Где искать?</h2>
# <div class="grid js-search-settings">
# <div class="grid-col grid-col-half">
# <p class="doc__text">
# <label>
# <input checked="" class="ui-radio js-toggle-input js-search-radio js-search-anywhere" id="search_place_all" name="search_full" type="radio" value="1"/>
# <span class="ui-text">везде</span>
# </label>
# </p>
# </div>
# <div class="grid-col grid-col-half">
# <p class="doc__text">
# <label>
# <input class="ui-radio js-toggle-input js-search-radio" id="search_place_src" name="search_full" type="radio" value="2"/>
# <span class="ui-text">укажите источник</span>
# </label>
# </p>
# </div>
# </div>
# <div class="ui-collapse js-toggle-collapse js-toggle-item" data-toggle-class-checked="ui-collapse--show" data-toggle-class-unchecked="ui-collapse--hide" data-toggle-id="search_place_all"></div>
# <div class="search__ui_indent ui-collapse js-toggle-collapse js-toggle-item" data-toggle-class-animated="ui-collapse--animated" data-toggle-class-checked="ui-collapse--show" data-toggle-class-unchecked="ui-collapse--hide" data-toggle-id="search_place_src">
# <p class="doc__text search__text_indent"><b>в материалах федеральных изданий</b></p>
# <ul class="search_list">
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-checkboxgroup" data-checkboxgroup-selector=".js-search-checkbox-federal" name="ru_all" type="checkbox"/>
# <span class="ui-text">
#                                 все  (8)                            </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="1"/>
# <span class="ui-text">
#                                 в газете «Коммерсантъ»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="6,34,52,61,62,198,242"/>
# <span class="ui-text">
#                                 в тематических приложениях  (6)                            </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="86,284,286"/>
# <span class="ui-text">
#                                 в лентах новостей                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="57,258,259,260,261,262,263,285,295,296,303"/>
# <span class="ui-text">
#                                 в материалах сайта  (2)                            </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="2"/>
# <span class="ui-text">
#                                 в журнале «Власть» и еженедельнике «Ъ»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="84"/>
# <span class="ui-text">
#                                 в журнале «Огонек»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="14"/>
# <span class="ui-text">
#                                 в журнале «Weekend»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="5"/>
# <span class="ui-text">
#                                 в журнале «Автопилот»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="3"/>
# <span class="ui-text">
#                                 в журнале «Деньги»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="217"/>
# <span class="ui-text">
#                                 в журнале «Наука»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="210"/>
# <span class="ui-text">
#                                 в материалах «Коммерсантъ FM»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="66"/>
# <span class="ui-text">
#                                 в журнале «Citizen K»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="17"/>
# <span class="ui-text">
#                                 в журнале «Секрет Фирмы»                             </span>
# </label>
# </li>
# </ul>
# <ul class="search_list">
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox js-search-checkbox-special" name="categories" type="checkbox" value="18"/>
# <span class="ui-text">
# <b>в фотогалереях</b> </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox js-search-checkbox-special" name="categories" type="checkbox" value="42"/>
# <span class="ui-text">
# <b>в спецпроектах</b> </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# ...
# <!--175-->
# <div id="adfox_1486973896119987"></div>
# <script>
#      window.yaContextCb.push(()=>{
#         Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1486973896119987',
#         params: Object.assign({
#             p1: 'bwfpj',
#             p2: 'fmox',
#             pct: 'c',
#             pp: 'g'
#         }, window.puids || {})
#     }, ['desktop'], {
#             tabletWidth: 1197.99,
#             phoneWidth: 1197.99,
#      })
#   })
# </script>
# </div>
# </div>
# </div>
# <div id="lenta">
# <aside class="grid-col-lenta aside_column">
# <section class="aside_news">
# <header class="aside_news__header">
# <h2 class="aside_news__header_name">
# <a class="link aside_news__header_link" href="/lenta">Лента</a>
# </h2>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <a class="title_more aside_news__more" href="/lenta">Вся лента</a>
# </header></section>
# </aside>
# <input class="hide" id="news_lenta_compact" type="checkbox"/>
# <section class="basement_news">
# <header class="basement_news__header">
# <div class="layout">
# <h2 class="basement_news__title">
# <a class="basement_news__link basement_news__header_link" href="#">Лента</a>
# </h2>
# <div class="basement_news__header_body hide_closed">
# </div>
# </div>
# </header>
# <div class="layout basement_news__body">
# <div class="basement_news__list">
# <article class="basement_news__item hide_opened">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# </div>
# </div>
# <footer class="basement_news__footer hide_closed">
# <div class="layout">
# <a class="basement_news__more" href="/lenta">Вся лента</a>
# </div>
# </footer>
# </section>
# </div>
# <footer class="footer">
# <div class="layout">
# <div class="grid main">
# <div class="footer_content">
# <div class="footer_section footer_rusfond">
# <a class="footer_rusfond__link footer__link" href="//rusfond.ru" target="_blank">
# <p class="footer__title footer__title--grey">Благотворительный фонд</p>
# <div class="footer_rusfond__logo">
# <picture class="js-lazyimage">
# <img alt="Русфонд" class="footer_rusfond__img js-lazyimage-source js-lazyimage-trigger" data-lazyimage-src="https://im.kommersant.ru/ContentFlex/images/redesign2020/rusfond_label.png" src="..."/>
# </picture>
# <noscript>
# <img alt="Русфонд" class="footer_rusfond__img fallback_image" src="https://im.kommersant.ru/ContentFlex/images/redesign2020/rusfond_label.png"/>
# </noscript>
# </div>
# </a>
# </div>
# <div class="footer_section footer_nav">
# <ul class="footer_nav__list">
# <li class="footer__title"><a class="footer__link" href="/about">О «Коммерсанте»</a></li>
# <li class="footer__title"><a class="footer__link" href="/archive">Архив</a></li>
# <li class="footer__title"><a class="footer__link" href="/contacts">Контакты</a></li>
# <li class="footer__title"><a class="footer__link" href="/ad">Реклама</a></li>
# <li class="footer__title"><a class="footer__link" href="/vacancies">Вакансии</a></li>
# </ul>
# <ul class="footer_nav__list">
# <li class="footer__title"><a class="footer__link" href="/digital">iOS&amp;Android</a></li>
# <li class="footer__title"><a class="footer__link" href="/LK/Feedback">Обратная связь</a></li>
# <li class="footer__title"><a class="footer__link" href="/copyright">Правовая информация</a></li>
# <li class="footer__title"><a class="footer__link" href="/lk/notification">E-mail рассылки</a></li>
# </ul>
# </div>
# <div class="footer_section footer_social">
# <!--                     <a href="https://www.facebook.com/kommersant.ru" class="footer_social__link" title="Фейсбук"> -->
# <!--                         <span class="vicon vicon--circled vicon--fb footer_social__icon"> -->
# <!--                             <svg class="vicon__body"> -->
# <!--                                 <use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="#vicon-fb"></use> -->
# <!--                             </svg> -->
# <!--                         </span> -->
# <!--                     </a> -->
# <a class="footer_social__link" href="https://vk.com/kommersant_ru" title="Вконтакте">
# <span class="vicon vicon--circled vicon--vk footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-vk" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <!--                     <a href="https://www.instagram.com/kommersant_online/" class="footer_social__link" title="Инстаграм"> -->
# <!--                         <span class="vicon vicon--circled vicon--ig footer_social__icon"> -->
# <!--                             <svg class="vicon__body"> -->
# <!--                                 <use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="#vicon-ig"></use> -->
# <!--                             </svg> -->
# <!--                         </span> -->
# <!--                     </a> -->
# <a class="footer_social__link" href="https://twitter.com/#!/kommersant" title="Твиттер">
# <span class="vicon vicon--circled vicon--tw footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-tw" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="footer_social__link" href="https://ok.ru/group/53942273310836" title="Одноклассники">
# <span class="vicon vicon--circled vicon--ok footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-ok" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="footer_social__link" href="https://t.me/kommersant" title="Телеграм">
# <span class="vicon vicon--circled vicon--tg footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-tg" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="footer_social__link" href="https://invite.viber.com/?g2=AQASKm3nkHYfLUfAeChUPQpUmuFiN6WagC%2B%2FFdwldgMHhadaBSbY6LiIYBwfMnfV" title="Вайбер">
# <span class="vicon vicon--circled vicon--vb footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-vb" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="footer_social__link" href="https://flipboard.com/@Kommersant" title="Флипборд">
# <span class="vicon vicon--circled vicon--flipboard footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-flipboard" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="footer_social__link" href="http://subscribe.ru/author/24276108/list" title="подписка на «Коммерсантъ»">
# <span class="vicon vicon--circled vicon--subscribe_service footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-subscribe-service" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <span class="footer__age">16+</span>
# </div>
# <div class="footer_section footer_adv">
# <p class="footer__title footer_adv__title footer__title--grey">Партнерские проекты/материалы, новости компаний, материалы с пометкой «Промо» и «Официальное сообщение» опубликованы на коммерческой основе</p>
# <div class="footer_counter hide_mobile">
# <div class="footer_counter__item">
# <!--LiveInternet logo-->
# <a href="http://www.liveinternet.ru/click" target="_blank">
# <img alt="" height="31" src="//counter.yadro.ru/logo?14.1" style="border: 0;" title="LiveInternet: показано число просмотров за 24 часа, посетителей за 24 часа и за сегодня" width="88"/>
# </a>
# <!--/LiveInternet-->
# </div>
# <div class="footer_counter__item">
# <!-- Rating@Mail.ru logo -->
# <a href="http://top.mail.ru/jump?from=84394" target="_blank">
# <img alt="Рейтинг@Mail.ru" height="31" src="//top-fwz1.mail.ru/counter?id=84394;t=487;l=1" style="border: 0;" width="88"/>
# </a>
# <!-- //Rating@Mail.ru logo -->
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script async="" src="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonAsyncJS.js?2203241811280000"></script>
# </body>
# </html>

# %%
# собираем все теги со ссылками на полные тексты новостей
refs = soup.find_all('a', class_='uho__link')
print(len(refs))
print(refs)
# Out:
# 26
# [<a class="uho__link uho__link--overlay" href="/doc/5271237?query=python" target="_blank">Расширение штата по всем направлениям!</a>, <a class="uho__link" href="/doc/5271237?query=python" target="_blank"> ...  (Java, .net, JS, <mark>Python</mark>, Golang, мобильная разработка ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5258915?query=python" target="_blank">EPAM System и JetBrains приостанавливают деятельность</a>, <a class="uho__link" href="/doc/5258915?query=python" target="_blank">IT-компании, арендовавшие в Петербурге десятки тысяч квадратных метров, переводят сотрудников в другие страны</a>, <a class="uho__link" href="/doc/5258915?query=python" target="_blank"> ... #, F#, C++, Ruby, <mark>Python</mark>, PHP, JavaScript и ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5238663?query=python" target="_blank">Porsche Macan в третьем поколении</a>, <a class="uho__link" href="/doc/5238663?query=python" target="_blank">Компания Porsche представила третье поколение моделей Macan, отличающихся от своих предшественников новой концепцией управления, а также более динамичными ходовыми качествами и энергичным дизайном</a>, <a class="uho__link" href="/doc/5238663?query=python" target="_blank"> ...  Metallic, а также <mark>Python</mark> Green для Macan ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5179940?query=python" target="_blank">Требуются продавцы. Срочно!</a>, <a class="uho__link" href="/doc/5179940?query=python" target="_blank">Топ-10 вакансий и резюме в Ярославской области в 2021 году</a>, <a class="uho__link" href="/doc/5179940?query=python" target="_blank"> ...  тыс. руб., «программист <mark>Python</mark>» — 137,5 тыс ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5171805?query=python" target="_blank">Два центра цифрового образования создадут в Удмуртии в 2022 году</a>, <a class="uho__link" href="/doc/5171805?query=python" target="_blank"> ...  учить программированию на <mark>Python</mark>, разработке VR/AR ...  направлениям: «Программирование на <mark>Python</mark>», «Разработка VR/AR ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5139396?query=python" target="_blank">Битва за кадры</a>, <a class="uho__link" href="/doc/5139396?query=python" target="_blank">Как государство помогает готовить специалистов для цифровой экономики</a>, <a class="uho__link" href="/doc/5139396?query=python" target="_blank"> ...  по Data Science, <mark>Python</mark>-разработчик, разработчик «1С ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5140728?query=python" target="_blank">Нижегородские школьники смогут бесплатно пройти курсы по программированию</a>, <a class="uho__link" href="/doc/5140728?query=python" target="_blank"> ...  изучению языков программирования <mark>Python</mark>, Java, С++ и ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5128850?query=python" target="_blank">Пензенских школьников будут обучать языкам программирования <mark>Python</mark> и Java</a>, <a class="uho__link" href="/doc/5128850?query=python" target="_blank"> ...  обучать языкам программирования <mark>Python</mark> и Java Пензенская ...  2035», обучение языкам <mark>Python</mark> и Java смогут ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5140840?query=python" target="_blank">IT: внимание, розыск</a>, <a class="uho__link" href="/doc/5140840?query=python" target="_blank">В Сибири растет дефицит специалистов в IT-сфере.</a>, <a class="uho__link" href="/doc/5140840?query=python" target="_blank"> ... ), девелоперов Java, C++, <mark>Python</mark>. Движение к дефициту ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5100393?query=python" target="_blank">У вас есть все данные</a>, <a class="uho__link" href="/doc/5100393?query=python" target="_blank">Почему Data Science-эксперты стали самыми востребованными специалистами сегодня</a>, <a class="uho__link" href="/doc/5100393?query=python" target="_blank"> ...  языками программирования, например <mark>Python ...

# %%
# добираемся до ссылок
all_links = []

for ref in refs:
    all_links.append(ref.get('href'))

print(len(all_links))
print(all_links)
# Out:
# 26
# ['/doc/5271237?query=python', '/doc/5271237?query=python', '/doc/5258915?query=python', '/doc/5258915?query=python', '/doc/5258915?query=python', '/doc/5238663?query=python', '/doc/5238663?query=python', '/doc/5238663?query=python', '/doc/5179940?query=python', '/doc/5179940?query=python', '/doc/5179940?query=python', '/doc/5171805?query=python', '/doc/5171805?query=python', '/doc/5139396?query=python', '/doc/5139396?query=python', '/doc/5139396?query=python', '/doc/5140728?query=python', '/doc/5140728?query=python', '/doc/5128850?query=python', '/doc/5128850?query=python', '/doc/5140840?query=python', '/doc/5140840?query=python', '/doc/5140840?query=python', '/doc/5100393?query=python', '/doc/5100393?query=python', '/doc/5100393?query=python']

# %%
# исключаем дубли
all_links = set(all_links)
print(len(all_links))
# Out:
# 10

# %%
# формируем полноценные ссылки
all_full_links = list(map(lambda x: 'https://www.kommersant.ru' + x, all_links))
print(all_full_links)
# Out:
# ['https://www.kommersant.ru/doc/5100393?query=python', 'https://www.kommersant.ru/doc/5128850?query=python', 'https://www.kommersant.ru/doc/5258915?query=python', 'https://www.kommersant.ru/doc/5171805?query=python', 'https://www.kommersant.ru/doc/5271237?query=python', 'https://www.kommersant.ru/doc/5140728?query=python', 'https://www.kommersant.ru/doc/5238663?query=python', 'https://www.kommersant.ru/doc/5140840?query=python', 'https://www.kommersant.ru/doc/5179940?query=python', 'https://www.kommersant.ru/doc/5139396?query=python']

# %%
# объединим все в одну функцию
def get_all_links(query):
    url = 'https://www.kommersant.ru/search/results'
    params = {
        'search_query': query,
    }
    res = requests.get(URL, params)
    soup = BeautifulSoup(res.text)
    refs = soup.find_all('a', class_='uho__link')

    all_links = []
    for ref in refs:
        all_links.append(ref.get('href'))
    
    all_links = set(all_links)

    all_full_links = list(map(lambda x: 'https://www.kommersant.ru' + x, all_links))

    return all_full_links

all_links = get_all_links('python')
print(all_links)
# Out:
# ['https://www.kommersant.ru/doc/5100393?query=python', 'https://www.kommersant.ru/doc/5128850?query=python', 'https://www.kommersant.ru/doc/5258915?query=python', 'https://www.kommersant.ru/doc/5171805?query=python', 'https://www.kommersant.ru/doc/5271237?query=python', 'https://www.kommersant.ru/doc/5140728?query=python', 'https://www.kommersant.ru/doc/5238663?query=python', 'https://www.kommersant.ru/doc/5140840?query=python', 'https://www.kommersant.ru/doc/5179940?query=python', 'https://www.kommersant.ru/doc/5139396?query=python']

# %%
# но мы же собрали только одну страницу? Хотим ВСЕ новости
def get_all_links(query, pages):
    url = 'https://www.kommersant.ru/search/results'
    links_list = []
    params = {
        'search_query': query
    }
    for i in range(1, pages+1):
        params['page'] = i
        res = requests.get(URL, params)
        time.sleep(0.33)

        refs = soup.find_all('a', class_='uho__link')
        all_links = []

        for ref in refs:
            all_links.append(ref.get('href'))
        
        all_links = set(all_links)

        all_full_links = list(map(lambda x: 'https://www.kommersant.ru' + x, all_links))

        links_list += all_full_links
    return links_list

all_links = get_all_links('python', 3)
print(len(all_links))
print(all_links)
# Out:
# 0
# []

# %%
for link in all_links:
    soup = BeautifulSoup(requests.get(link).text)
    time.sleep(0.33)
    date = pd.to_datetime(soup.find('time', class_='doc_header__publish_time').get('datetime'))
    print(date)
    title = soup.find('h1', class_='doc_header__name').text.strip()
    print(title)
    text = soup.find('div', class_='doc__body').text.strip()
    print(text)

# %%
# запишем данные в датафрейм
kom_news = pd.DataFrame()
for link in all_links:
    soup = BeautifulSoup(requests.get(link).text)
    time.sleep(0.3)
    date = pd.to_datetime(soup.find('time', class_='doc_header__publish_time').get('datetime'))
    title = soup.find('h1', class_='doc_header__name').text.strip()
    text = soup.find('div', class_='doc__body').text.strip().replace('\n', '')
    row = {'date': date, 'title': title, 'text': text}
    kom_news = pd.concat([kom_news, pd.DataFrame([row])])  
kom_news
# Out:
#                        date  \
# 0 2021-12-02 00:00:01+03:00
# 0 2021-12-13 12:53:40+03:00
# 0 2022-03-16 00:03:00+03:00
# 0 2022-01-18 10:14:53+03:00
# 0 2022-03-23 12:23:11+03:00
# 0 2021-12-20 17:37:05+03:00
# 0 2022-03-01 17:23:56+03:00
# 0 2021-12-06 00:00:00+03:00
# 0 2022-01-21 13:23:20+03:00
# 0 2021-12-28 00:01:00+03:00
# 0 2021-12-02 00:00:01+03:00
# 0 2021-12-13 12:53:40+03:00
# 0 2022-03-16 00:03:00+03:00
# 0 2022-01-18 10:14:53+03:00
# 0 2022-03-23 12:23:11+03:00
# 0 2021-12-20 17:37:05+03:00
# 0 2022-03-01 17:23:56+03:00
# 0 2021-12-06 00:00:00+03:00
# 0 2022-01-21 13:23:20+03:00
# 0 2021-12-28 00:01:00+03:00
# 0 2021-12-02 00:00:01+03:00
# 0 2021-12-13 12:53:40+03:00
# 0 2022-03-16 00:03:00+03:00
# 0 2022-01-18 10:14:53+03:00
# 0 2022-03-23 12:23:11+03:00
# 0 2021-12-20 17:37:05+03:00
# 0 2022-03-01 17:23:56+03:00
# 0 2021-12-06 00:00:00+03:00
# 0 2022-01-21 13:23:20+03:00
# 0 2021-12-28 00:01:00+03:00
# 0 2021-12-02 00:00:01+03:00
# 0 2021-12-13 12:53:40+03:00
# 0 2022-03-16 00:03:00+03:00
# 0 2022-01-18 10:14:53+03:00
# 0 2022-03-23 12:23:11+03:00
# 0 2021-12-20 17:37:05+03:00
# 0 2022-03-01 17:23:56+03:00
# 0 2021-12-06 00:00:00+03:00
# 0 2022-01-21 13:23:20+03:00
# 0 2021-12-28 00:01:00+03:00
# 0 2021-12-02 00:00:01+03:00
# 0 2021-12-13 12:53:40+03:00
# 0 2022-03-16 00:03:00+03:00
# 0 2022-01-18 10:14:53+03:00
# 0 2022-03-23 12:23:11+03:00
# 0 2021-12-20 17:37:05+03:00
# 0 2022-03-01 17:23:56+03:00
# 0 2021-12-06 00:00:00+03:00
# 0 2022-01-21 13:23:20+03:00
# 0 2021-12-28 00:01:00+03:00
#
#                                                title  \
# 0                              У вас есть все данные
# 0  Пензенских школьников будут обучать языкам про...
# 0  EPAM System и JetBrains приостанавливают деяте...
# 0  Два центра цифрового образования создадут в Уд...
# 0             Расширение штата по всем направлениям!
# 0  Нижегородские школьники смогут бесплатно пройт...
# 0                  Porsche Macan в третьем поколении
# 0                               IT: внимание, розыск
# 0                        Требуются продавцы. Срочно!
# 0                                     Битва за кадры
# 0                              У вас есть все данные
# 0  Пензенских школьников будут обучать языкам про...
# 0  EPAM System и JetBrains приостанавливают деяте...
# 0  Два центра цифрового образования создадут в Уд...
# 0             Расширение штата по всем направлениям!
# 0  Нижегородские школьники смогут бесплатно пройт...
# 0                  Porsche Macan в третьем поколении
# 0                               IT: внимание, розыск
# 0                        Требуются продавцы. Срочно!
# 0                                     Битва за кадры
# 0                              У вас есть все данные
# 0  Пензенских школьников будут обучать языкам про...
# 0  EPAM System и JetBrains приостанавливают деяте...
# 0  Два центра цифрового образования создадут в Уд...
# 0             Расширение штата по всем направлениям!
# 0  Нижегородские школьники смогут бесплатно пройт...
# 0                  Porsche Macan в третьем поколении
# 0                               IT: внимание, розыск
# 0                        Требуются продавцы. Срочно!
# 0                                     Битва за кадры
# 0                              У вас есть все данные
# 0  Пензенских школьников будут обучать языкам про...
# 0  EPAM System и JetBrains приостанавливают деяте...
# 0  Два центра цифрового образования создадут в Уд...
# 0             Расширение штата по всем направлениям!
# 0  Нижегородские школьники смогут бесплатно пройт...
# 0                  Porsche Macan в третьем поколении
# 0                               IT: внимание, розыск
# 0                        Требуются продавцы. Срочно!
# 0                                     Битва за кадры
# 0                              У вас есть все данные
# 0  Пензенских школьников будут обучать языкам про...
# 0  EPAM System и JetBrains приостанавливают деяте...
# 0  Два центра цифрового образования создадут в Уд...
# 0             Расширение штата по всем направлениям!
# 0  Нижегородские школьники смогут бесплатно пройт...
# 0                  Porsche Macan в третьем поколении
# 0                               IT: внимание, розыск
# 0                        Требуются продавцы. Срочно!
# 0                                     Битва за кадры
#
#                                                 text
# 0  1K\r    \r                8 мин.\r            ...
# 0  161\r    \r                1 мин.\r           ...
# 0  3K\r    \r                5 мин.\r            ...
# 0  374\r    \r                1 мин.\r           ...
# 0  74\r    \r                1 мин.\r            ...
# 0  394\r    \r                1 мин.\r           ...
# 0  19\r    \r                3 мин.\r            ...
# 0  2K\r    \r                7 мин.\r            ...
# 0  3K\r    \r                1 мин.\r            ...
# 0  496\r    \r                8 мин.\r           ...
# 0  1K\r    \r                8 мин.\r            ...
# 0  161\r    \r                1 мин.\r           ...
# 0  3K\r    \r                5 мин.\r            ...
# 0  374\r    \r                1 мин.\r           ...
# 0  74\r    \r                1 мин.\r            ...
# 0  394\r    \r                1 мин.\r           ...
# 0  19\r    \r                3 мин.\r            ...
# 0  2K\r    \r                7 мин.\r            ...
# 0  3K\r    \r                1 мин.\r            ...
# 0  496\r    \r                8 мин.\r           ...
# 0  1K\r    \r                8 мин.\r            ...
# 0  161\r    \r                1 мин.\r           ...
# 0  3K\r    \r                5 мин.\r            ...
# 0  374\r    \r                1 мин.\r           ...
# 0  74\r    \r                1 мин.\r            ...
# 0  394\r    \r                1 мин.\r           ...
# 0  19\r    \r                3 мин.\r            ...
# 0  2K\r    \r                7 мин.\r            ...
# 0  3K\r    \r                1 мин.\r            ...
# 0  496\r    \r                8 мин.\r           ...
# 0  1K\r    \r                8 мин.\r            ...
# 0  161\r    \r                1 мин.\r           ...
# 0  3K\r    \r                5 мин.\r            ...
# 0  374\r    \r                1 мин.\r           ...
# 0  74\r    \r                1 мин.\r            ...
# 0  394\r    \r                1 мин.\r           ...
# 0  19\r    \r                3 мин.\r            ...
# 0  2K\r    \r                7 мин.\r            ...
# 0  3K\r    \r                1 мин.\r            ...
# 0  496\r    \r                8 мин.\r           ...
# 0  1K\r    \r                8 мин.\r            ...
# 0  161\r    \r                1 мин.\r           ...
# 0  3K\r    \r                5 мин.\r            ...
# 0  374\r    \r                1 мин.\r           ...
# 0  74\r    \r                1 мин.\r            ...
# 0  394\r    \r                1 мин.\r           ...
# 0  19\r    \r                3 мин.\r            ...
# 0  2K\r    \r                7 мин.\r            ...
# 0  3K\r    \r                1 мин.\r            ...
# 0  496\r    \r                8 мин.\r           ...

# %%
# обернем в функцию 
def get_kom_news(links):
    kom_news = pd.DataFrame()
    for link in all_links:
        soup = BeautifulSoup(requests.get(link).text)
        time.sleep(0.3)
        date = pd.to_datetime(soup.find('time', class_='doc_header__publish_time').get('datetime'))
        title = soup.find('h1', class_='doc_header__name').text.strip()
        text = soup.find('div', class_='doc__body').text.strip().replace('\n', '')
        row = {'date': date, 'title': title, 'text': text}
        kom_news = pd.concat([kom_news, pd.DataFrame([row])])  
    return kom_news.reset_index(drop=True)

# %%
kom_news = get_kom_news(all_links)
display(kom_news)
